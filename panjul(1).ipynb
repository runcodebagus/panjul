# %%
import tweepy
from tweepy import OAuthHandler
import json
import pandas as pd

consumer_key="BizW5ryIDWkjAv2TVgRHL9yFH"
consumer_secret="2u15AAM7YgGRDQmFH30y7NpxMJwriOyZFRD3gmhE7yBr9sTHKh"
access_token="1448928724800344071-BjFMhEGkRPrHIigKGpmWHaDVxtk32H"
access_secret="ruBQNk91olJeJiavkpYH5uTkqufF4zHr2S12lTDThalLK"

auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
keyword = ['kominfo']

text,created_at,user_name,id = [],[],[],[]
for kw in keyword :
  for tweet in tweepy.Cursor(api.search, q=['kominfo'], rpp=300, count=300, date_since="2022-01-01", include_entities=True, lang="id").items(3000):
      text.append(tweet.text)
      created_at.append(tweet.created_at)
      user_name.append(tweet.user.name)
      id.append(tweet.user.id)
    
list_ = {'text': text, 
         'Created At' : created_at,
         'Username' : user_name,
         'id' : id}

df = pd.DataFrame(list_)
df.to_csv("kominfo.csv")
df
# Out:
#                                                    text          Created At  \
# 0     @tanyakanrl Buat warga twitter semuanya, kalo ... 2022-07-19 16:09:35
# 1     RT @1998ur_: Kalo twitter jadi diblock sama ko... 2022-07-19 16:09:33
# 2     RT @ezash: H-1 sebelum kominfo (katanya) block... 2022-07-19 16:09:31
# 3     RT @tbzdayz: gmn ya cara gue sebarin ke semua ... 2022-07-19 16:09:30
# 4     RT @1998ur_: Kalo twitter jadi diblock sama ko... 2022-07-19 16:09:29
# ...                                                 ...                 ...
# 2995  RT @spaghettoniii: pov warga indonesia pas kom... 2022-07-19 15:23:43
# 2996  RT @Relyourbae2: Kalo Twitter beneran diblokir... 2022-07-19 15:23:43
# 2997  RT @ezash: H-1 sebelum kominfo (katanya) block... 2022-07-19 15:23:42
# 2998  RT @Relyourbae2: Kalo Twitter beneran diblokir... 2022-07-19 15:23:42
# 2999  RT @Relyourbae2: Kalo Twitter beneran diblokir... 2022-07-19 15:23:41
#
#                Username                   id
# 0                aprill  1313289073528729600
# 1          forverotonad  1485509609268064258
# 2              xhra୧⍤⃝🦧   974552299199606785
# 3                    de  1158702229664124928
# 4                    Ze  1148933490756313088
# ...                 ...                  ...
# 2995         KeitoKeito  1209763681719816192
# 2996               loay  1169260321401212928
# 2997     Eka Novia Sari            192206072
# 2998                  Y  1086979582333337600
# 2999  Jajanan kpop di 📌  1015256615212146688
#
# [3000 rows x 4 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install varname
# !pip install keras-metrics
# !pip install h5py
# !pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting varname
#   Downloading varname-0.9.0-py3-none-any.whl (22 kB)
# Collecting executing<0.10,>=0.9
#   Downloading executing-0.9.1-py2.py3-none-any.whl (16 kB)
# Installing collected packages: executing, varname
# Successfully installed executing-0.9.1 varname-0.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-metrics
#   Downloading keras_metrics-1.1.0-py2.py3-none-any.whl (5.6 kB)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.7/dist-packages (from keras-metrics) (2.8.0)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 7.3 MB/s
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
import tweepy
from tweepy import OAuthHandler
import nltk
import pandas as pd
import re
import tensorflow as tf
import time
import multiprocessing
import io
import gensim
import numpy as np
import matplotlib.pyplot as plt
import keras_metrics as km
import pickle
import keras
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
from tensorflow import keras
import textblob           
from textblob import TextBlob
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers import Dense, Activation, Embedding, LSTM, Bidirectional, Dropout,GRU
from keras import regularizers
from keras.models import load_model
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn import metrics
from nltk.tokenize import TweetTokenizer
from collections import defaultdict
from datetime import timedelta
from gensim.models import word2vec
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score, precision_score, recall_score,confusion_matrix, accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from varname import nameof
from sklearn.tree import DecisionTreeClassifier
from nltk.tokenize import word_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


nltk.download('punkt')
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import pandas as pd #untuk membaca data
import numpy as np #untuk kebutuhan dalam menganalisis data seperti operasi vektor dan matriks
import csv



data = pd.read_csv("/content/drive/MyDrive/Tugas akhir TA/sofanjih2.csv")

data
# Out:
#                                                    text    label            id
# 0     RT @feiitoteles @pinguin________ Lu yang tolol...  positif  9.310000e+07
# 1     RT @idextratime Tolol emang lu viet sama thai,...  positif  2.786674e+09
# 2     RT ,Aduh si tolol emang. Kesel banget https://...  positif  7.450000e+08
# 3     RT @Hayat_aL_Fatih @detikcom Terus bestie boco...  negatif  1.450000e+18
# 4     RT "Dasar tolol nyakitin mulu lo bangsat, gagu...  positif  7.660000e+17
# ...                                                 ...      ...           ...
# 1124  130,"@graham_asscot Nahhhh ... E mail kita pun...  positif  1.050000e+18
# 1125  132,RT @akidoverseas: Gw gak takut sama blokir...  negatif  1.500000e+18
# 1126  144,"RT @kittenjihan: @akiheyyyyyyy @convomf K...  positif  1.290000e+18
# 1127  145,"RT @BayKnight03: @resir014 @nden ""ketika...  positif  4.060000e+09
# 1128  153,"hi kominfo, tolong sekalian blokir kemisk...  negatif  1.250000e+18
#
# [1129 rows x 3 columns]

# %%
data.drop_duplicates(subset='text',keep=False, inplace=True)

data
# Out:
#                                                    text    label            id
# 0     RT @feiitoteles @pinguin________ Lu yang tolol...  positif  9.310000e+07
# 1     RT @idextratime Tolol emang lu viet sama thai,...  positif  2.786674e+09
# 2     RT ,Aduh si tolol emang. Kesel banget https://...  positif  7.450000e+08
# 3     RT @Hayat_aL_Fatih @detikcom Terus bestie boco...  negatif  1.450000e+18
# 4     RT "Dasar tolol nyakitin mulu lo bangsat, gagu...  positif  7.660000e+17
# ...                                                 ...      ...           ...
# 1124  130,"@graham_asscot Nahhhh ... E mail kita pun...  positif  1.050000e+18
# 1125  132,RT @akidoverseas: Gw gak takut sama blokir...  negatif  1.500000e+18
# 1126  144,"RT @kittenjihan: @akiheyyyyyyy @convomf K...  positif  1.290000e+18
# 1127  145,"RT @BayKnight03: @resir014 @nden ""ketika...  positif  4.060000e+09
# 1128  153,"hi kominfo, tolong sekalian blokir kemisk...  negatif  1.250000e+18
#
# [1129 rows x 3 columns]

# %% [markdown]
# CASEFOLDING

# %%
#mengubah seluruh huruf menjadi huruf keci
data['text'] = data['text'].str.lower()

print('Hasil CaseFolding :\n')
print(data['text'])
print('\n\n\n')
# Out:
# Hasil CaseFolding :
#
# 0       rt @feiitoteles @pinguin________ lu yang tolol...
# 1       rt @idextratime tolol emang lu viet sama thai,...
# 2       rt ,aduh si tolol emang. kesel banget https://...
# 3       rt @hayat_al_fatih @detikcom terus bestie boco...
# 4       rt "dasar tolol nyakitin mulu lo bangsat, gagu...
#                               ...
# 1124    130,"@graham_asscot nahhhh ... e mail kita pun...
# 1125    132,rt @akidoverseas: gw gak takut sama blokir...
# 1126    144,"rt @kittenjihan: @akiheyyyyyyy @convomf k...
# 1127    145,"rt @bayknight03: @resir014 @nden ""ketika...
# 1128    153,"hi kominfo, tolong sekalian blokir kemisk...
# Name: text, Length: 1129, dtype: object

# %% [markdown]
# FILTERING

# %%
from nltk.text import Text
import string #digunakan untuk menangani string ataupun substring
import nltk #untuk memproses teks seperti melakukan classification, tokenization, stemming dll
import re #urutan karakter yang membentuk pola pencarian

#hapus teks khusus
def remove_text_special(text):
  text = text.replace('\\t', " ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
  text = text.encode('ascii','replace').decode('ascii')
  text = ' '.join(re.sub("[!”#$%&’()*+,-./:;<=>?@[\]^_`{|}~][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ",text).split())

  return text.replace("http://"," ").replace("https://"," ")

  data['text'] = data['text'].apply(remove_text_special)
#hapus nomor
def remove_number(text):
 return re.sub(r"\d+", "", text)
data['text'] = data['text'].apply(remove_number)

#hilangkan tanda baca
def remove_punctuation(text):
  return text.translate(str.maketrans("","",string.punctuation))

data['text'] = data['text'].apply(remove_punctuation)

#hapus spasi
def remove_whitespace_LT(text):
  return text.strip()

data['text'] = data['text'].apply(remove_whitespace_LT)

#hapus beberapa spasi putih menjadi spasi tunggal
def remove_whitespace_multiple(text):
  return re.sub('\s+',' ', text)

data['text'] = data['text'].apply(remove_whitespace_multiple)

#menghapus char
def remove_singl_char(text):
  return re.sub(r"\b[a-zA-Z]\b","", text)

data['text'] = data['text'].apply(remove_singl_char)

# %% [markdown]
# TOKENIZING

# %%
#tahap pemotongan string masukan berdasarkan kata- kata yang menyusunnya atau dengan kata lain pemecahan kalimat menjadi kata

from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download("punkt")

#pembungkus tokenize kata
def word_tokenize_wrapper(text):
  return word_tokenize (text)
data['text_tokens'] = data['text'].apply(word_tokenize_wrapper)

print('Hasil Tokenizing :\n')
print(data['text_tokens'].head())
print('\n\n\n')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Hasil Tokenizing :
#
# 0    [rt, feiitoteles, pinguin, lu, yang, tolol, ðÿ...
# 1    [rt, idextratime, tolol, emang, lu, viet, sama...
# 2    [rt, aduh, si, tolol, emang, kesel, banget, ht...
# 3    [rt, hayatalfatih, detikcom, terus, bestie, bo...
# 4    [rt, dasar, tolol, nyakitin, mulu, lo, bangsat...
# Name: text_tokens, dtype: object

# %%
def freqDist_wrapper(text): #menghitung kemunculan kata dalam satu kalimat
  return FreqDist(text)

data['text_tokens_fdist'] = data['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n')
print(data['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(rt, 1), (feiitoteles, 1), (pinguin, 1), (lu,...
# 1    [(rt, 1), (idextratime, 1), (tolol, 1), (emang...
# 2    [(rt, 1), (aduh, 1), (si, 1), (tolol, 1), (ema...
# 3    [(rt, 1), (hayatalfatih, 1), (detikcom, 1), (t...
# 4    [(rt, 1), (dasar, 1), (tolol, 1), (nyakitin, 1...
# Name: text_tokens_fdist, dtype: object

# %% [markdown]
# STOPWORD

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")

list_stopwords = stopwords.words('indonesian')


list_stopwords.extend(["yg","dg","rt","dgn","ny","klo","lu","tdk",
                      'utk','kalo','smpe','biar','bkin','blang','gak',
                      'ga','krn','nya','nih','sih','si','tau',
                      'tuh','ya','jd','jgn','jg','aja','n','t','kr',
                      'nyg','hehe','wkwk','loh','elu','rt','amp','&amp','yah'])

#konversi daftar ke kamus
list_stopwords = set(list_stopwords)

#hapus stopword pada token list
def stopwords_removal(words):
	return [word for word in words if word not in list_stopwords]

data['text_tokens_WSW'] = data['text_tokens'].apply(stopwords_removal)

print(data['text_tokens_WSW'].head())
# Out:
# 0     [feiitoteles, pinguin, tolol, ðÿ™†ðÿ¿â€â™‚ï¸]
# 1    [idextratime, tolol, emang, viet, thai, jiahel...
# 2    [aduh, tolol, emang, kesel, banget, httpstcogh...
# 3    [hayatalfatih, detikcom, bestie, bocor, curhat...
# 4    [dasar, tolol, nyakitin, mulu, lo, bangsat, ga...
# Name: text_tokens_WSW, dtype: object
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip3 install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.3.2.tar.gz (825 kB)
#      |████████████████████████████████| 825 kB 7.9 MB/s
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Collecting psutil>=5.6.6
#   Downloading psutil-5.9.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 74.1 MB/s
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 75.2 MB/s
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.8.1)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.2-py3-none-any.whl size=16199 sha256=fdf63713d2d0aabc72767c99d63d0761f6c21ecde93634af2c439f618eb5e716
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/74/64543a9fcef6095b5e9428e21674fd208c8ce372a58ffbc818
# Successfully built swifter
# Installing collected packages: locket, partd, fsspec, psutil, swifter
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed fsspec-2022.5.0 locket-1.0.0 partd-1.2.0 psutil-5.9.1 swifter-1.3.2

# %%
data.head()
# Out:
#                                                 text    label            id  \
# 0  rt feiitoteles pinguin lu yang tolol ðÿ™†ðÿ¿â...  positif  9.310000e+07
# 1  rt idextratime tolol emang lu viet sama thai j...  positif  2.786674e+09
# 2  rt aduh si tolol emang kesel banget httpstcogh...  positif  7.450000e+08
# 3  rt hayatalfatih detikcom terus bestie bocor ka...  negatif  1.450000e+18
# 4  rt dasar tolol nyakitin mulu lo bangsat gaguna...  positif  7.660000e+17
#
#                                          text_tokens  \
# 0  [rt, feiitoteles, pinguin, lu, yang, tolol, ðÿ...
# 1  [rt, idextratime, tolol, emang, lu, viet, sama...
# 2  [rt, aduh, si, tolol, emang, kesel, banget, ht...
# 3  [rt, hayatalfatih, detikcom, terus, bestie, bo...
# 4  [rt, dasar, tolol, nyakitin, mulu, lo, bangsat...
#
#                                    text_tokens_fdist  \
# 0  {'rt': 1, 'feiitoteles': 1, 'pinguin': 1, 'lu'...
# 1  {'rt': 1, 'idextratime': 1, 'tolol': 1, 'emang...
# 2  {'rt': 1, 'aduh': 1, 'si': 1, 'tolol': 1, 'ema...
# 3  {'rt': 1, 'hayatalfatih': 1, 'detikcom': 1, 't...
# 4  {'rt': 1, 'dasar': 1, 'tolol': 1, 'nyakitin': ...
#
#                                      text_tokens_WSW
# 0   [feiitoteles, pinguin, tolol, ðÿ™†ðÿ¿â€â™‚ï¸]
# 1  [idextratime, tolol, emang, viet, thai, jiahel...
# 2  [aduh, tolol, emang, kesel, banget, httpstcogh...
# 3  [hayatalfatih, detikcom, bestie, bocor, curhat...
# 4  [dasar, tolol, nyakitin, mulu, lo, bangsat, ga...

# %%
# !pip3 install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %% [markdown]
# STEMMING

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

#Buat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

#stemming
def stemmed_wrapper(term):
	return stemmer.stem(term)

term_dict = {}

for document in data['text_tokens_WSW']:
  for term in document :
    if term not in term_dict:
      term_dict[term] = ' '
print(len(term_dict))
print("-------------------")

for term in term_dict:
  term_dict[term] = stemmed_wrapper(term)
  print(term, ":" ,term_dict[term])

print(term_dict)
print("-------------------")

#terapkan istilah stemming ke dataframe
def get_stemmed_term(document):
	return [term_dict[term] for term in document]

data['text_tokens_stemmed'] = data['text_tokens_WSW'].swifter.apply(get_stemmed_term)
print(data['text_tokens_stemmed'])
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# mengendus : endus
# piara : piara
# jauhâ€¦ : jauh
# httpstcogeoxuckr : httpstcogeoxuckr
# raden : raden
# antasenaðÿ‡®ðÿ‡©ðÿ‡®ðÿ‡©ðÿ‡®ðÿ‡© : antasena
# gila : gila
# dibuka : buka
# bersih : bersih
# jing : jing
# periksaâ€¦ : periksa
# httpstcocpmxurxch : httpstcocpmxurxch
# protagonist : protagonist
# jaryoko : jaryoko
# bpkri : bpkri
# dki : dki
# terbuang : buang
# siaâ² : sia
# juve : juve
# diehard : diehard
# adi : adi
# ferrynlangelo : ferrynlangelo
# pelacak : lacak
# gercep : gercep
# ngga : ngga
# mengâ€¦ : meng
# httpstcozitwvib : httpstcozitwvib
# leonitalestari : leonitalestari
# lbh : lbh
# memelihara : pelihara
# biaya : biaya
# perawatan : awat
# murah : murah
# ðÿ‡®ðÿ‡©choðÿ‡®ðÿ‡© : cho
# ngusut : ngusut
# dkijakarta : dkijakarta
# kelar : kelar
# httpstcotpjhoktdpj : httpstcotpjhoktdpj
# download : download
# aplikasiâ€¦ : aplikasi
# httpstcoctooksgu : httpstcoctooksgu
# srilangka : srilangka
# pemimpin : pimpin
# ugalugalan : ugalugalan
# membangun : bangun
# dibiayai : biaya
# china : china
# kampungnya : kampung
# rajapaksa : rajapaksa
# dibikinlâ€¦ : dibikinl
# shey : shey
# laily : laily
# tjhinfar : tjhinfar
# bangkrut : bangkrut
# sri : sri
# mulyani : mulyani
# beh : beh
# httpstcokwgauqbaw : httpstcokwgauqbaw
# muslimah : muslimah
# kadomainan : kadomainan
# siantar : siantar
# langka : langka
# menghukum : hukum
# amplop : amplop
# pengusaha : usaha
# tegasâ€¦ : tegas
# karaeng : karaeng
# pudji : pudji
# beruntung : untung
# memiliki : milik
# komoditi : komoditi
# tambang : tambang
# dll : dll
# pembangunan : bangun
# ugalugalanâ€¦ : ugalugalan
# teguh : teguh
# supriyadi : supriyadi
# khairulusman : khairulusman
# srilanka : srilanka
# ngamuk : ngamuk
# kediaman : diam
# pm : pm
# diobrak : diobrak
# abrik : abrik
# dibakar : bakar
# massa : massa
# melarikan : lari
# sampaiâ€¦ : sampai
# generasi : generasi
# zaman : zaman
# sloka : sloka
# diatasâ€¦ : atas
# httpstcojceuzjnv : httpstcojceuzjnv
# tony : tony
# fox : fox
# channel : channel
# presâ€¦ : pres
# httpstcofxzl : httpstcofxzl
# modal : modal
# ayat : ayat
# mayat : mayat
# wiwikherma : wiwikherma
# fokus : fokus
# syiar : syiar
# diserang : serang
# mengaku : aku
# agâ€¦ : ag
# kedubes : dubes
# buka : buka
# stand : stand
# fair : fair
# kosong : kosong
# ngapain : ngapain
# negaranya : negara
# abis : abis
# httpstcowxnirwnktr : httpstcowxnirwnktr
# ryan : ryan
# panji : panji
# mardiko : mardiko
# bbprasetya : bbprasetya
# mencari : cari
# terobosan : terobos
# mendukung : dukung
# ketahanan : tahan
# pangan : pangan
# regulations : regulations
# suaâ€¦ : sua
# prasetyaðÿ‡®ðÿ‡© : prasetya
# maju : maju
# bermartabatðÿ‡®ðÿ‡© : martabat
# muhammadsaewad : muhammadsaewad
# bernama : nama
# araban : arab
# pencinta : cinta
# narasi : narasi
# memecah : pecah
# belah : belah
# min : min
# jng : jng
# spt : spt
# rakyatâ€¦ : rakyat
# httpstcoxldunyfthi : httpstcoxldunyfthi
# sufi : sufi
# anis : anis
# disalahkan : salah
# pendukungnya : dukung
# ganjar : ganjar
# kelomok : kelomok
# sedikâ€¦ : dik
# httpstcoclhdrxugbx : httpstcoclhdrxugbx
# kutipanrinduu : kutipanrinduu
# aturan : atur
# kapitalisme : kapitalisme
# ribanya : riba
# menjadâ€¦ : menjad
# httpstcoxweapzkey : httpstcoxweapzkey
# hamumza : hamumza
# markasnyajoki : markasnyajoki
# dilarang : larang
# mencantumkan : cantum
# pribadi : pribadi
# nomer : nomer
# ewallet : ewallet
# menfess : menfess
# mengirim : kirim
# berbauâ€¦ : bau
# httpstcohakgxksiiw : httpstcohakgxksiiw
# murka : murka
# lanka : lanka
# disembunyikan : sembunyi
# koranjakarta : koranjakarta
# mondialâ€¦ : mondial
# httpstcoarcnzatu : httpstcoarcnzatu
# koran : koran
# fansafaridd : fansafaridd
# aryprasetyo : aryprasetyo
# pendapat : dapat
# berdasarkan : dasar
# rusuh : rusuh
# httpstcohspetlkg : httpstcohspetlkg
# doelpaten : doelpaten
# indikator : indikator
# bangkrutnya : bangkrut
# proyek : proyek
# ugalan : ugalan
# sperti : sperti
# pelabuhan : labuh
# henry : henry
# setiawan : setiawan
# herlambang : herlambang
# oposisicerdas : oposisicerdas
# terlena : lena
# pujian : puji
# dimakannya : makan
# lihat : lihat
# ahmad : ahmad
# kekirim : kirim
# anjinggg : anjinggg
# ludo : ludo
# game : game
# kaga : kaga
# cipokkkk : cipokkkk
# httpstcolpncvsqc : httpstcolpncvsqc
# ejar : ejar
# perjuanganku : juang
# gold : gold
# dapetin : dapetin
# euntae : euntae
# bangsaaattttt : bangsaaattttt
# ðÿ¥¢ :
# bngt : bngt
# ngentt : ngentt
# ayzel : ayzel
# â½ :
# natalia : natalia
# gunslopy : gunslopy
# moonton : moonton
# ðÿ˜­ :
# popokman : popokman
# puyeng : puyeng
# grafik : grafik
# kotak : kotak
# berliano : berliano
# weyxa : weyxa
# montoon : montoon
# runa : runa
# kidd : kidd
# opickinst : opickinst
# kconkdhere : kconkdhere
# pssi : pssi
# gambarnya : gambar
# epep : epep
# mr : mr
# brownstone : brownstone
# mamoyyoii : mamoyyoii
# ngep : ngep
# yanto : yanto
# kates : kates
# pointbroo : pointbroo
# golongannya : golong
# dihormati : hormat
# puraâ€¦ : pura
# httpstcolrrixcekkx : httpstcolrrixcekkx
# mengandung : kandung
# saraterorkebencian : saraterorkebencian
# stumble : stumble
# anj : anj
# kucing : kucing
# jerapah : jerapah
# hðÿ…°rvey : h rvey
# cfaw : cfaw
# yatuhan : yatuhan
# ps : ps
# matinya : mati
# bawaannya : bawa
# dimaenin : dimaenin
# grafiknya : grafik
# mikir : mikir
# bicara : bicara
# konstitusi : konstitusi
# polarisasi : polarisasi
# kebenâ€¦ : keben
# httpstcohmuocxjf : httpstcohmuocxjf
# huangtrisha : huangtrisha
# really : really
# setauku : tau
# berat : berat
# mod : mod
# ray : ray
# tracing : tracing
# minecraft : minecraft
# cuz : cuz
# httpstcoqhlnuane : httpstcoqhlnuane
# wira : wira
# fospersija : fospersija
# persija : persija
# set : set
# gilaaa : gilaaa
# gio : gio
# syaifrhyahooco : syaifrhyahooco
# ramdani : ramdani
# jak : jak
# wkwkwkwk : wkwkwkwk
# papahjokdri : papahjokdri
# pssleman : pssleman
# bandung : bandung
# maaf : maaf
# ogah : ogah
# rharhudets : rharhudets
# sugmadiig : sugmadiig
# muklas : muklas
# banding : banding
# pt : pt
# apaa : apaa
# sapi : sapi
# perah : perah
# httpstcotpsyrxsob : httpstcotpsyrxsob
# dont : dont
# be : be
# moved : moved
# alisyarief : alisyarief
# batunya : batu
# nikita : nikita
# mirzani : mirzani
# resmi : resmi
# ditetapkan : tetap
# httpstcoqmkiyxdnw : httpstcoqmkiyxdnw
# nanang : nanang
# junawar : junawar
# polres : polres
# kota : kota
# tetapkan : tetap
# httpstcowefteymo : httpstcowefteymo
# raphael : raphael
# ezha : ezha
# vs : vs
# dito : dito
# mahendra : mahendra
# berujung : ujung
# penggeledahan : geledah
# httpstcoyavtpmpx : httpstcoyavtpmpx
# solopos : solopos
# keitung : keitung
# kelapaðÿ˜®â€ðÿ : kelapa
# ¨ :
# tnya : tnya
# nitik : nitik
# manual : manual
# zoom : zoom
# assaâ€¦ : assa
# httpstcoelluea : httpstcoelluea
# afifah : afifah
# kerjainsalah : kerjainsalah
# curang : curang
# linnnnðÿ§¸ðÿª : linnnn
# jayheauxx : jayheauxx
# sumpahin : sumpahin
# bahagia : bahagia
# bgst : bgst
# debu : debu
# cosmic : cosmic
# cih : cih
# caption : caption
# sibal : sibal
# ktnya : ktnya
# anti : anti
# nntn : nntn
# drakor : drakor
# nelen : nelen
# ludah : ludah
# sndri : sndri
# taejun : taejun
# tros : tros
# mleyot : mleyot
# melebur : lebur
# meleleh : leleh
# parah : parah
# anying : anying
# alð–§· : al
# wanderluct : wanderluct
# gausa : gausa
# cuti : cuti
# pekaan : peka
# orgnya : orgnya
# mistis : mistis
# ceritain : ceritain
# kisah : kisah
# sakti : sakti
# mampusâ€¦ : mampus
# httpstcolatfonksy : httpstcolatfonksy
# ikiww : ikiww
# callaaa : callaaa
# chan : chan
# nyanyiin : nyanyiin
# fav : fav
# mantan : mantan
# aaaaaaaaaaaaaaaaaaa : aaaaaaaaaaaaaaaaaaa
# ðÿš :
# ðÿ¤¯ðÿ¤¯ðÿ¤¯ðÿ¤¯ðÿ¥µðÿ¥µðÿ¥µðÿ¥µðÿ¥´ðÿ¥´ðÿ¥´ðÿ¥´ :
# httpstconycwhrzg : httpstconycwhrzg
# calla : calla
# mhs : mhs
# gmn : gmn
# mangkenye : mangkenye
# kebiasaan : biasa
# titip : titip
# absen : absen
# ccâ€¦ : cc
# httpstcozqptttdqt : httpstcozqptttdqt
# winona : winona
# amanda : amanda
# jago : jago
# pecundang : cundang
# aj : aj
# httpstcodnyavohl : httpstcodnyavohl
# ðÿ‡®ðÿ‡©with : with
# heartðÿ‡®ðÿ‡© : heart
# kurangin : rangin
# diperhatiin : diperhatiin
# ortu : ortu
# dirumah : rumah
# httpstconjcypsruy : httpstconjcypsruy
# ra : ra
# leeyeonjin : leeyeonjin
# senangnya : senang
# keributan : ribut
# sabiru : sabiru
# nichosilalah : nichosilalah
# gratiachan : gratiachan
# temenin : temenin
# ntar : ntar
# kampus : kampus
# ssss : ssss
# ngeyoutube : ngeyoutube
# gatau : gatau
# algoritma : algoritma
# konten : konten
# youtube : youtube
# midzyðÿ¤£ðÿ¤£ : midzy
# ngajakâ€¦ : ngajak
# httpstcoffynsmpgx : httpstcoffynsmpgx
# ðÿœ¸ðÿ :
# « :
# askrlfess : askrlfess
# nay : nay
# gajadi : gajadi
# sarapan : sarap
# ky : ky
# tanyain : tanyain
# menguntungkan : untung
# ¬ð :
# ªð :
# ¾ð :
# ½ð :
# ªðÿœ :
# ðÿ :
# hiduplu : hiduplu
# sumpahan : sumpah
# mimpi : mimpi
# buruk : buruk
# terusss : terusss
# tenamg : tenamg
# httpstcobkaasuf : httpstcobkaasuf
# ciiww : ciiww
# ujungnya : ujung
# menyalahkan : salah
# memojokkan : pojok
# kepercayaan : percaya
# httpstcoqtykpnpv : httpstcoqtykpnpv
# rosadym : rosadym
# ditimpah : ditimpah
# besih : besih
# digebuk : gebuk
# level : level
# akud : akud
# nico : nico
# martin : martin
# pakpahan : pakpahan
# takut : takut
# malaikat : malaikat
# maut : maut
# kah : kah
# titid : titid
# bedua : bedua
# nyatu : nyatu
# disamber : disamber
# nyawa : nyawa
# httpstcoutzhqzrwew : httpstcoutzhqzrwew
# claire : claire
# kayturnus : kayturnus
# belagu : belagu
# mentangâ² : mentang
# ptnðÿ–•ðÿ : ptn
# smg : smg
# ngerjain : ngerjain
# skripsi : skripsi
# persulit : sulit
# â™¡ì·â—žâƒ• :
# â¸¼â‚‰ :
# õ¢îá‰¢ :
# â­ :
# komunis : komunis
# anjeng : anjeng
# rbennington : rbennington
# bolacomid : bolacomid
# so : so
# kefinal : final
# laos : laos
# juara : juara
# zhaf : zhaf
# siaranbolalive : siaranbolalive
# yumeiwan : yumeiwan
# awokwokwokwok : awokwokwokwok
# httpstcotobvhfjh : httpstcotobvhfjh
# î¹ñƒî±ð¸ :
# karma : karma
# wakakakaka : wakakakaka
# changsuekth : changsuekth
# sucay : sucay
# pelat : pelat
# boong : boong
# arekapal : arekapal
# benerinpeci : benerinpeci
# haha : haha
# pra : pra
# sii : sii
# reffan : reffan
# saputra : saputra
# dihajar : hajar
# semi : semi
# abay : abay
# vietnamfans : vietnamfans
# ðÿ–•ðÿ–• :
# httpstcoosmrfcbkdd : httpstcoosmrfcbkdd
# chairul : chairul
# final : final
# malaymampus : malaymampus
# ajig : ajig
# nannoying : nannoying
# halah : halah
# taingaku : taingaku
# gigi : gigi
# copot : copot
# videoin : videoin
# simpatimampus : simpatimampus
# clow : clow
# zaitulabidi : zaitulabidi
# affu : affu
# httpstcompsogttg : httpstcompsogttg
# syamsuddin : syamsuddin
# sukurin : sukurin
# timnas : timnas
# malesan : malesan
# akting : akting
# rasâ€¦ : ras
# httpstconffsvlo : httpstconffsvlo
# kangazis : kangazis
# thaitea : thaitea
# tim : tim
# jelek : jelek
# bapuk : bapuk
# mental : mental
# tempe : tempe
# broww : broww
# yo : yo
# kirain : kirain
# eh : eh
# gong : gong
# kosoâ€¦ : koso
# httpstcofnkqhyiit : httpstcofnkqhyiit
# chandra : chandra
# septiadi : septiadi
# theaseanball : theaseanball
# imbas : imbas
# teror : teror
# suporter : suporter
# indonesiaatau : indonesiaatau
# aff : aff
# indonesiâ€¦ : indonesi
# httpstcoemkwrje : httpstcoemkwrje
# world : world
# pranks : pranks
# memefess : memefess
# kntol : kntol
# halo : halo
# guys : guys
# ðÿœ™ :
# fammalaysia : fammalaysia
# good : good
# job : job
# adiwisnu : adiwisnu
# laksana : laksana
# hahahaha : hahahaha
# bola : bola
# kedengkian : dengki
# wâ€¦ : w
# httpstcopcfrqahxpi : httpstcopcfrqahxpi
# agâš¡ : ag
# luh : luh
# dihinain : dihinain
# dibayar : bayar
# tuntas : tuntas
# karmanya : karma
# adex : adex
# modar : modar
# tahilan : tahil
# gabisa : gabisa
# chellenge : chellenge
# kar : kar
# santorinissun : santorinissun
# comberan : comberan
# biji : biji
# matalu : matalu
# congkel : congkel
# rizal : rizal
# bawa : bawa
# motor : motor
# ngerokok : ngerokok
# doain : doain
# mulut : mulut
# sariawan : sariawan
# kelilipan : kelilip
# httpstcosaxkxzuxob : httpstcosaxkxzuxob
# ðÿ¥° :
# babikenapa : babikenapa
# ngk : ngk
# dormampussss : dormampussss
# wkwkwkwkkwk : wkwkwkwkkwk
# ronnys : ronnys
# bergaya : gaya
# sesuai : sesuai
# isi : isi
# dompet : dompet
# ðš— :
# updatebolabola : updatebolabola
# awowkwokwokwokwowk : awowkwokwokwokwowk
# nguyen : nguyen
# kualitas : kualitas
# pau : pau
# suckerattes : suckerattes
# bekashitt : bekashitt
# astagfirullah : astagfirullah
# tobat : tobat
# anjg : anjg
# cepuin : cepuin
# sean : sean
# soksokan : soksokan
# suci : suci
# nulisnulis : nulisnulis
# au : au
# dientot : entot
# wkwkwkk : wkwkwkk
# ù‹ :
# gebuk : gebuk
# yaa : yaa
# ðÿ˜†ðÿ˜†ðÿ˜† :
# mampuss : mampuss
# mampuâ€¦ : mampu
# httpstcorquwfugh : httpstcorquwfugh
# alexan : alexan
# temen : temen
# mabar : mabar
# afk : afk
# direport : direport
# ngurang : ngurang
# kredit : kredit
# scorenya : scorenya
# wkwkwk : wkwkwk
# mlbb : mlbb
# amasanusi : amasanusi
# bandotbandot : bandotbandot
# licik : licik
# actforhumanity : actforhumanity
# ðÿ˜¡ðÿ˜¡ :
# musibah : musibah
# colong : colong
# bangsatâ€¦ : bangsat
# httpstcotmjwkrqjg : httpstcotmjwkrqjg
# doni : doni
# dodol : dodol
# oncom : oncom
# tiktok : tiktok
# disban : disban
# disben : disben
# anjinggggggg : anjinggggggg
# httpstcoweksnjh : httpstcoweksnjh
# raineken : raineken
# € :
# siregar : siregar
# noor : noor
# michael : michael
# membalas : balas
# dendam : dendam
# kebaikan : baik
# perbuatan : buat
# menimbulkan : timbul
# masyarakat : masyarakat
# penipu : tipu
# ketipu : tipu
# nipu : nipu
# jjoy : jjoy
# open : open
# gestun : gestun
# spaylater : spaylater
# instan : instan
# wholejayy : wholejayy
# bot : bot
# haven : haven
# ekowboy : ekowboy
# video : video
# kampanye : kampanye
# diprotes : protes
# jual : jual
# ketakutan : takut
# thdp : thdp
# benturkan : bentur
# pancasila : pancasila
# semprot : semprot
# baygon : baygon
# seraaang : seraaang
# tergeletak : geletak
# kebalik : balik
# berdaya : daya
# dalem : dalem
# ruby : ruby
# askrl : askrl
# nenek : nenek
# ngeselin : ngeselin
# bangett : bangett
# anjrot : anjrot
# kambing : kambing
# httpstcozplekgg : httpstcozplekgg
# bangetbapak : bangetbapak
# kandung : kandung
# bejatnya : bejat
# nerakaklo : nerakaklo
# msh : msh
# kenadinerakaâ€¦ : kenadineraka
# httpstcokonmnaujpd : httpstcokonmnaujpd
# elza : elza
# frozen : frozen
# â :
# petirnya : petir
# zeus : zeus
# httpstcokmyvucrwgs : httpstcokmyvucrwgs
# afðÿ¦‹ : af
# secakep : cakep
# ngehina : ngehina
# hah : hah
# jomblo : jomblo
# seumur : umur
# httpstcowfhzrfdfq : httpstcowfhzrfdfq
# kale : kale
# moonareas : moonareas
# yeu : yeu
# kutuk : kutuk
# kutu : kutu
# jew : jew
# ðÿœ¸ :
# wkwkkw : wkwkkw
# kuyang : kuyang
# hayooo : hayooo
# ndin : ndin
# sikatsikat : sikatsikat
# ikatancintaep : ikatancintaep
# berasa : asa
# andin : andin
# ngaca : ngaca
# kemaren : kemaren
# minun : minun
# cocacola : cocacola
# sembuhsembuh : sembuhsembuh
# httpstcoqnecsuytl : httpstcoqnecsuytl
# kennyie : kennyie
# niki : nik
# ðÿ¤² :
# holifiaa : holifiaa
# nape : nape
# disuru : disuru
# mochiiðÿ£ : mochi
# iye : iye
# investasi : investasi
# bodong : bodong
# nanaâ€¢ðÿ° : nana
# namonlyours : namonlyours
# convomfs : convomfs
# beban : beban
# cancel : cancel
# gojeknya : gojek
# biarin : biarin
# gâ€¦ : g
# fadðÿƒ : fad
# specters : specters
# nerf : nerf
# mob : mob
# genshin : genshin
# strain : strain
# nupursharmabjp : nupursharmabjp
# you : you
# fucking : fucking
# shit : shit
# membusuk : busuk
# neraka : neraka
# kwontol : kwontol
# reza : reza
# za : za
# theeagleben : theeagleben
# mencalonkan : calon
# dicalonkan : calon
# bayangkan : bayang
# numpuk : numpuk
# harta : harta
# hidâ€¦ : hid
# httpstcondktvvwo : httpstcondktvvwo
# rasyid : rasyid
# snihyamitvayi : snihyamitvayi
# rasrantacc : rasrantacc
# wasiat : wasiat
# keluargaâ€¦ : keluarga
# httpstcoqgqmaywu : httpstcoqgqmaywu
# erte : erte
# nonperiode : nonperiode
# balikinnya : balikinnya
# meecin : meecin
# sidang : sidang
# dadar : dadar
# price : price
# tag : tag
# ðÿ· :
# bojonebojoku : bojonebojoku
# bahar : bahar
# kepret : kepret
# httpstcokucopbd : httpstcokucopbd
# dry : dry
# bool : bool
# dilabrak : labrak
# bencong : bencong
# wkwkwkwkwkwkwk : wkwkwkwkwkwkwk
# lebayatun : lebayatun
# dramastuti : dramastuti
# wkwkwkw : wkwkwkw
# dikritik : kritik
# coach : coach
# ðÿ¤£ðÿ :
#  :
# ketinggalan : tinggal
# ndeso : ndeso
# shin : shin
# berâ€¦ : ber
# httpstcotlscjtradq : httpstcotlscjtradq
# bbelino : bbelino
# ðÿ‡®ðÿ‡©ðÿ¸âš½ï¸ :
# get : get
# soon : soon
# marselino : marselino
# affpresse : affpresse
# bom : bom
# netizen : netizen
# indo : indo
# kmns : kmns
# bertopeng : topeng
# sport : sport
# deddy : deddy
# mulyawan : mulyawan
# feeladelphia : feeladelphia
# moga : moga
# tunjukkan : tunjuk
# sejelasjelasnya : sejelasjelasnya
# lembut : lembut
# reda : reda
# sekolah : sekolah
# kondisinya : kondisi
# aâ€¦ : a
# httpstcoimievwiw : httpstcoimievwiw
# couch : couch
# beezz : beezz
# indosupporter : indosupporter
# â€œmampus : mampus
# panitia : panitia
# lolosâ€ : lolos
# kuepay : kuepay
# ditipu : tipu
# turnamen : turnamen
# mickey : mickey
# pearson : pearson
# terjebak : jebak
# ambisi : ambisi
# karakter : karakter
# anime : anime
# rasaain : rasaain
# panggil : panggil
# angga : angga
# dazaigojo : dazaigojo
# wkakakaka : wkakakaka
# gosat : gosat
# comberanðÿ¤£ðÿ¤£ðÿ¤£ : comberan
# fei : fei
# ayuxmine : ayuxmine
# yu : yu
# ayu : ayu
# ngejatohin : ngejatohin
# lisa : lisa
# jatohnya : jatohnya
# jamin : jamin
# fans : fans
# httpstcoczsechwjy : httpstcoczsechwjy
# karin : karin
# hobi : hobi
# nanyain : nanyain
# nikah : nikah
# musim : musim
# kondangan : kondangan
# kfir : kfir
# franco : franco
# mmeg : mmeg
# enk : enk
# kambek : kambek
# httpstcogluzghbhd : httpstcogluzghbhd
# coseryuu : coseryuu
# kecoa : kecoa
# suruh : suruh
# akhlak : akhlak
# httpstcomgxuwdj : httpstcomgxuwdj
# yoki : yoki
# kabonn : kabonn
# kebanyakan : banyak
# gimmick : gimmick
# mba : mba
# yustin : yustin
# han : han
# zik : zik
# takbiran : takbir
# mushola : mushola
# suaranya : suara
# diteriakin : diteriakin
# bercanda : canda
# maâ€¦ : ma
# httpstcocvqhbaf : httpstcocvqhbaf
# my : my
# drpda : drpda
# blok : blok
# ragil : ragil
# eatmoarntacos : eatmoarntacos
# taehyung : taehyung
# gasuka : gasuka
# bts : bts
# army : army
# come : come
# katnis : katnis
# memek : memek
# akhirat : akhirat
# belatung : belatung
# lahar : lahar
# gunung : gunung
# paku : paku
# tabur : tabur
# bonâ€¦ : bon
# httpstcoodmpueoa : httpstcoodmpueoa
# rere : rere
# ritualnya : ritual
# gblk : gblk
# gab : gab
# ðÿ¦– :
# sarkas : sarkas
# ngak : ngak
# block : block
# batalin : batalin
# grabnya : grabnya
# httpstcovseggrwk : httpstcovseggrwk
# ðÿ¥€manðÿ¥€ : man
# mengakibatkan : akibat
# otakmu : otak
# keram : keram
# putin : putin
# pidatonya : pidato
# httpstcoksgayiyq : httpstcoksgayiyq
# dee : dee
# â‚šëšà­§â¤âƒâœ¿â™¡ :
# eyeltie : eyeltie
# horanggiee : horanggiee
# up : up
# jt : jt
# balikin : balikin
# nyettt : nyettt
# idul : idul
# adha : adha
# nihhh : nihhh
# bisaâ€nya : bisa nya
# httpstcocupngeljom : httpstcocupngeljom
# pukupipaw : pukupipaw
# tiket : tiket
# next : next
# konser : konser
# menandingi : tanding
# konsâ€¦ : kons
# kiaðÿ‡ò : kia
# â‚‚â‚† :
# âš¹ :
# sorry : sorry
# httpstcobyqhcbll : httpstcobyqhcbll
# azra : azra
# skip : skip
# kl : kl
# status : status
# pendem : pendem
# ampe : ampe
# lega : lega
# mendem : mendem
# urusan : urus
# sopâ€¦ : sop
# httpstcoouixzahskg : httpstcoouixzahskg
# ð• :
# ð¢ :
# ð :
# jfbðÿ¦‹ : jfb
# kontl : kontl
# ngntd : ngntd
# entod : entod
# hamil : hamil
# satrio : satrio
# la : la
# hamak : hamak
# voucher : voucher
# dh : dh
# expired : expired
# pakai : pakai
# btull : btull
# gi : gi
# lunlbang : lunlbang
# burit : burit
# wkakak : wkakak
# ryeonggguuuuuu : ryeonggguuuuuu
# road : road
# to : to
# harum : harum
# manis : manis
# like : like
# plis : plis
# muncul : muncul
# beranda : beranda
# tl : tl
# tab : tab
# likes : likes
# senâ€¦ : sen
# httpstcoomuibllvju : httpstcoomuibllvju
# partigarihit : partigarihit
# tengok : tengok
# timelinenya : timelinenya
# dimana : mana
# om : om
# imajinasop : imajinasop
# gemanjing : ganjing
# ketempean : tempe
# ðÿ˜œðÿ™ :
# sadgirl : sadgirl
# hukumdan : hukumdan
# bentar : bentar
# letoy : letoy
# tinggal : tinggal
# menunggu : tunggu
# samâ€¦ : sam
# httpstcodspghan : httpstcodspghan
# korea : korea
# mantup : mantup
# pakdeoye : pakdeoye
# thalomoan : thalomoan
# yupptanpa : yupptanpa
# disadari : sadar
# memupuk : pupuk
# mentalnya : mental
# sasha : sasha
# atoismail : atoismail
# nataliuspigai : nataliuspigai
# coklatpun : coklat
# kucingâ€¦ : kucing
# httpstconbieoke : httpstconbieoke
# she : she
# doesnt : doesnt
# deserve : deserve
# anw : anw
# ratu : ratu
# dikerjain : dikerjain
# fadhli : fadhli
# rizqi : rizqi
# diem : diem
# ulti : ulti
# milan : mil
# httpstcolgclimfjnv : httpstcolgclimfjnv
# ðÿž¸ :
# najis : najis
# penjara : penjara
# benja : benja
# txtmlbb : txtmlbb
# ngontol : ngontol
# â€² :
# terkutuk : kutuk
# lh : lh
# httpstcoetiwcy : httpstcoetiwcy
# pedenya : pedenya
# dekel : dekel
# ngajarin : ngajarin
# ngeootdgaya : ngeootdgaya
# dpn : dpn
# kmra : kmra
# eeh : eeh
# ngeliat : ngeliat
# galeri : galeri
# tercengang : cengang
# publish : publish
# missqueenðÿ : missqueen
# sbtcon : sbtcon
# sbt : sbt
# buyer : buyer
# hnr : hnr
# seller : seller
# scammer : scammer
# app : app
# messagesosmedmu : messagesosmedmu
# error : error
# dihubungi : hubung
# goa : goa
# aðÿ¦‹ : a
# robbykarman : robbykarman
# indra : indra
# kenz : kenz
# salmanan : salmanan
# ketangkep : ketangkep
# reaksi : reaksi
# afiliator : afiliator
# holywings : holywings
# haraâ€¦ : hara
# sasustus : sasustus
# fullyvaccinated : fullyvaccinated
# mukanya : muka
# butek : butek
# bangga : bangga
# penghianat : penghianat
# at : at
# end : end
# httpstcoyzmyddwz : httpstcoyzmyddwz
# kimjibeomwaifu : kimjibeomwaifu
# sam : sam
# kya : kya
# ajg : ajg
# hmm : hmm
# syukur : syukur
# paksaâ€¦ : paksa
# httpstcouxjlelfa : httpstcouxjlelfa
# natasya : natasya
# krisspreet : krisspreet
# nangis : nang
# edi : edi
# mulyadi : mulyadi
# terburuk : buruk
# inggris : inggris
# gegara : gegara
# chelsea : chelsea
# dipaksa : paksa
# ðÿ˜ :
# httpstconjoysugxp : httpstconjoysugxp
# haji : haji
# umar : umar
# hasibuan : hasibuan
# febikyraj : febikyraj
# giginpraginanto : giginpraginanto
# militer : militer
# lemah : lemah
# maksudnya : maksud
# yakok : yakok
# tega : tega
# kekuatan : kuat
# sendiricoba : sendiricoba
# perbanyak : banyak
# liteâ€¦ : lite
# jamet : jamet
# seindo : seindo
# kakðÿ™ : kak
# bunyi : bunyi
# opening : opening
# netfix : netfix
# httpstcogfjvcifm : httpstcogfjvcifm
# cat : cat
# calling : calling
# super : super
# duper : duper
# nyaman : nyaman
# jogja : jogja
# terkhusus : khusus
# daerah : daerah
# wonokromo : wonokromo
# nginden : nginden
# sarrryyyðÿ­ : sarrryyy
# rukia : rukia
# premium : premium
# ðÿƒcio : cio
# stillsya : stillsya
# emm : emm
# km : km
# shen : shen
# ðÿ†–ðÿ†ž :
# mlpabjiepep : mlpabjiepep
# seru : seru
# temenkenangancerita : temenkenangancerita
# seburuk : buruk
# httpstcoxnxkzm : httpstcoxnxkzm
# tetew : tetew
# lycangirls : lycangirls
# abangan : abangan
# citayem : citayem
# ahmd : ahmd
# arlecchine : arlecchine
# retrofrade : retrofrade
# contristans : contristans
# junkyu : junkyu
# asli : asli
# httpstcoobjtfelj : httpstcoobjtfelj
# scbd : scbd
# fashion : fashion
# week : week
# sumpah : sumpah
# style : style
# seleâ€¦ : sele
# muammar : muammar
# naufal : naufal
# budiman : budiman
# vcjinsoul : vcjinsoul
# ikutan : ikut
# kak : kak
# diwawancara : wawancara
# bonge : bonge
# sunbaenim : sunbaenim
# sunwoo : sunwoo
# acara : acara
# pekanbaru : pekanbaru
# senayan : senayan
# bojong : bojong
# depok : depok
# ðÿ˜­ðÿ˜­ðÿ˜­ :
# httpstcozeamoawka : httpstcozeamoawka
# mel : mel
# ðÿ§¸ðÿ¦‹ :
# xahiyou : xahiyou
# join : join
# sirkel : sirkel
# citayemðÿ˜¢ : citayem
# xaviera : xaviera
# taepridez : taepridez
# cursedkidd : cursedkidd
# vanilla : vanilla
# â™¡ :
# dipukulin : dipukulin
# rama : rama
# oyenjingga : oyenjingga
# gtw : gtw
# yakk : yakk
# outpit : outpit
# mormaid : mormaid
# ðÿ§œðÿ :
# â€â™€ï¸ :
# princepotterx : princepotterx
# jmt : jmt
# mw : mw
# ðÿ˜ :
# jol : jol
# vengaeance : vengaeance
# sickoseth : sickoseth
# sedih : sedih
# dibubarin : dibubarin
# gina : gina
# sudirman : sudirman
# et : et
# aqin : aqin
# ekonporno : ekonporno
# rake : rake
# ðÿ…±ï¸ijer : ijer
# reyhanmahendra : reyhanmahendra
# tvindonesiawkwk : tvindonesiawkwk
# cangtip : cangtip
# chai : chai
# frustasi : frustasi
# arc : arc
# hujan : hujan
# cepet : cepet
# rapat : rapat
# begal : begal
# xxnicherry : xxnicherry
# hayuuuk : hayuuuk
# fesyen : fesyen
# wik : wik
# rydho : rydho
# putra : putra
# hebatnya : hebat
# internet : internet
# branding : branding
# sarang : sarang
# nabrak : nabrak
# trend : trend
# terlebihâ€¦ : lebih
# httpstcovjsfhrw : httpstcovjsfhrw
# gus : gus
# kentoce : kentoce
# tengang : tengang
# terganggu : ganggu
# tiktokers : tiktokers
# manfaaâ€¦ : manfaa
# httpstcoqkkrdysbr : httpstcoqkkrdysbr
# lou : lou
# orangorang : orangorang
# tauuu : tauuu
# luluuuuu : luluuuuu
# baechute : baechute
# oiiviam : oiiviam
# dinik : nik
# les : les
# lahh : lahh
# punta : punta
# wrna : wrna
# rmbut : rmbut
# jmet : jmet
# ðš :
# ð‚ici : ici
# ðšysie : ysie
# ayangnyameguro : ayangnyameguro
# bund : bund
# keinget : keinget
# lagii : lagi
# papa : papa
# jametnya : jametnya
# versi : versi
# ã‚ã‚ :
# skarang : skarang
# nanya : nanya
# ngerasa : ngerasa
# gamau : gamau
# ajak : ajak
# healing : healing
# httpstcocxqfvryjg : httpstcocxqfvryjg
# esa : esa
# anugrahðÿ : anugrah
# ° :
# naon : naon
# weekðÿ¤£ðÿ¤£ðÿ¤£ : week
# jimjoy : jimjoy
# pites : pites
# pitesin : pitesin
# pesen : sen
# wikðÿ˜­ðÿ˜­ : wik
# â‹† :
# magdaleneid : magdaleneid
# remaja : remaja
# cerminan : cermin
# kelompok : kelompok
# memutuskan : putus
# oranâ€¦ : oran
# oreo : oreo
# taylors : taylors
# version : version
# superior : superior
# ngumpul : ngumpul
# disi : disi
# katronya : katronya
# bandit : bandit
# reot : reot
# ngerti : ngerti
# salty : salty
# nak : nak
# oke : oke
# ajâ€¦ : aj
# httpstcokcdszgtnf : httpstcokcdszgtnf
# æ :
# ›ä¼¼ :
# brand : brand
# niatan : niat
# campaign : campaign
# makeover : makeover
# penampilan : tampil
# tarâ€¦ : tar
# httpstcoqjlwodtq : httpstcoqjlwodtq
# aisyah : aisyah
# rahma : rahma
# utami : utami
# hotman : hotman
# paris : paris
# menyebut : sebut
# roy : roy
# penggantinya : ganti
# viral : viral
# sosial : sosial
# sâ€¦ : s
# httpstcorormu : httpstcorormu
# tribunlombokcom : tribunlombokcom
# jehunity : jehunity
# pindah : pindah
# cikarang : cikarang
# ðÿ :
# aowkaoaka : aowkaoaka
# httpstcobbebqozws : httpstcobbebqozws
# karen : karen
# ðÿ—¯ðÿ¤ÿ :
# kurma : kurma
# sukari : sukar
# ajwa : ajwa
# aninðÿ‡µðÿ‡¸ : anin
# alfax : alfax
# ðÿ¤œðÿ¤›ðÿ :
# › :
# kcptenz : kcptenz
# ketua : ketua
# himpunan : himpun
# ø˜ :
# aryalangit : aryalangit
# dinopattidjalal : dinopattidjalal
# wamenlu : wamenlu
# nambah : nambah
# sesat : sesat
# alealedaisuki : alealedaisuki
# bct : bct
# ezi : ezi
# yaallah : yaallah
# asa : asa
# mneh : mneh
# maluin : maluin
# httpstcodyupsbvp : httpstcodyupsbvp
# â—â€¢á´—â€¢â—âœ§ã€‚ :
# aduu : aduu
# verenti : verenti
# ketawa : ketawa
# mix : mix
# ngentottttt : ngentottttt
# dimas : mas
# anjirrr : anjirrr
# tv : tv
# transtv : transtv
# bakat : bakat
# modalan : modal
# panggung : panggung
# £ :
# ï¸ï¸ :
# vibes : vibes
# berentiin : berentiin
# truk : truk
# kvn : kvn
# wqwq : wqwq
# local : local
# pride : pride
# ekeke : ekeke
# itemtreez : itemtreez
# renchin : renchin
# iyaapp : iyaapp
# jdi : jdi
# itutuh : itutuh
# nongkrong : nongkrong
# diplesetin : diplesetin
# sudâ€¦ : sud
# httpstcocbihtpi : httpstcocbihtpi
# zee : zee
# citayam : citayam
# alhamdulilah : alhamdulilah
# puji : puji
# pesyen : pesyen
# ekspektasi : ekspektasi
# kwetiiauuw : kwetiiauuw
# jinkkkk : jinkkkk
# begaul : begaul
# nan : nan
# vondegurechafff : vondegurechafff
# txtfrombrand : txtfrombrand
# semenjak : semenjak
# fyp : fyp
# direkamâ€¦ : rekam
# httpstcomomhykqdl : httpstcomomhykqdl
# jejeðÿ¦ : jeje
# begoooooo : begoooooo
# bangettttttttttttt : bangettttttttttttt
# budak : budak
# pinkquinnn : pinkquinnn
# guoblok : guoblok
# sihðÿ : sih
# ‡ :
# httpstcokxpfkgbqy : httpstcokxpfkgbqy
# sukadam : sukadam
# kadam : kadam
# tempodotco : tempodotco
# pendapatan : dapat
# sebulan : bulan
# diatas : atas
# rb : rb
# dianggap : anggap
# sasttrr : sasttrr
# tetanga : tetanga
# tikus : tikus
# rakus : rakus
# surabaya : surabaya
# ditumpas : tumpas
# apanya : apa
# cerdas : cerdas
# hancur : hancur
# bukti : bukti
# nasib : nasib
# bangsa : bangsa
# menular : tular
# ketololanya : ketololanya
# pengikutnya : ikut
# indiehome : indiehome
# kacau : kacau
# saking : saking
# kesal : kesal
# teknisi : teknisi
# pergi : pergi
# jugansampe : jugansampe
# ketebelece : ketebelece
# dirjen : dirjen
# menulis : tulis
# kompas : kompas
# engak : engak
# jam : jam
# berbohong : bohong
# junjungan : junjung
# bani : bani
# sialan : sial
# memancing : pancing
# fishing : fishing
# rihlah : rihlah
# arisan : arisan
# gantipresiden : gantipresiden
# pondok : pondok
# lawu : lawu
# cisarua : cisarua
# keadilan : adil
# aseng : aseng
# medsosnya : medsosnya
# diblokir : blokir
# impor : impor
# ganyang : ganyang
# didepan : depan
# gedung : gedung
# dewan : dewan
# perwakilan : wakil
# kawan : kawan
# tertawa : tertawa
# senang : senang
# cewek : cewek
# dilepasin : dilepasin
# mbaknya : mbak
# angkutan : angkut
# gang : gang
# rapist : rapist
# kunyuk : kunyuk
# mobilnya : mobil
# ngegas : ngegas
# kejamnya : kejam
# jejak : jejak
# digital : digital
# narkotika : narkotika
# psikotropika : psikotropika
# obat : obat
# terlarang : larang
# junimendo : junimendo
# williaqueen : williaqueen
# benerkacau : benerkacau
# damput : damput
# mbakdia : mbakdia
# kuli : kuli
# politik : politik
# penderita : derita
# phobia : phobia
# danâ€¦ : dan
# mengapai : kapai
# bawel : bawel
# koreksi : koreksi
# beliau : beliau
# lengserkan : lengser
# pencitran : pencitran
# wikipedia : wikipedia
# orde : orde
# pemerintahan : perintah
# junta : junta
# myanmar : myanmar
# diktator : diktator
# mengunakan : mengunakan
# fasilitas : fasilitas
# daster : daster
# hina : hina
# sensi : sensi
# menyatukan : satu
# elemen : elemen
# lintas : lintas
# bukanya : buka
# tandingan : tanding
# berasal : asal
# budaya : budaya
# adat : adat
# perasan : peras
# axis : axis
# mingu : mingu
# jaringanya : jaringanya
# pandangan : pandang
# benahi : benah
# selamatkan : selamat
# kasusnya : kasus
# usir : usir
# budha : budha
# myamar : myamar
# perbedan : bedan
# cocok : cocok
# keparat : keparat
# mundur : mundur
# huhahahahahanpengusaha : huhahahahahanpengusaha
# menangis : menang
# ber : ber
# darah : darah
# sangking : sangking
# susahnya : susah
# mengelola : kelola
# benernberas : benernberas
# sembilan : sembilan
# daya : daya
# bany : bany
# butut : butut
# solerout : solerout
# herjosout : herjosout
# sekenario : sekenario
# siapkan : siap
# melemahkanmembinasakan : melemahkanmembinasakan
# kpkalau : kpkalau
# imbasny : imbasny
# ganti : ganti
# profesional : profesional
# jelasin : jelasin
# ncowo : ncowo
# burungnya : burung
# cewenya : cewenya
# bernada : nada
# nsiapa : nsiapa
# transgender : transgender
# nyanyi : nyanyi
# kehebatan : hebat
# wajibkudu : wajibkudu
# wakil : wakil
# rakyatdpr : rakyatdpr
# pangil : pangil
# terhormat : hormat
# muliakerjanya : muliakerjanya
# mengaco : aco
# ayo : ayo
# ramai : ramai
# putih : putih
# kodok : kodok
# macan : macan
# asia : asia
# jauhcma : jauhcma
# dongok : dongok
# mengelu : elu
# munafik : munafik
# figur : figur
# asing : asing
# kubu : kubu
# oposan : oposan
# kbanyakan : kbanyakan
# oplosan : oplos
# tetapjokowi : tetapjokowi
# grombolan : grombolan
# kadal : kadal
# jidat : jidat
# gosongmg : gosongmg
# sukanya : suka
# ribut : ribut
# grombolanya : grombolanya
# pura : pura
# budekdasar : budekdasar
# cingkrang : cingkrang
# penciuman : cium
# tajam : tajam
# pencarian : cari
# uangups : uangups
# penghutangan : hutang
# merekayasa : rekayasa
# terorisme : terorisme
# citra : citra
# menuduh : tuduh
# militan : militan
# radikal : radikal
# garis : garis
# menyudutkan : sudut
# isu : isu
# lgbt : lgbt
# mencurigai : curiga
# banyaknya : banyak
# projo : projo
# tendensius : tendensius
# berbau : bau
# ditambah : tambah
# sebelah : belah
# merek : merek
# ributkan : ribut
# otoriter : otoriter
# patung : patung
# bolehnya : boleh
# badminton : badminton
# putri : putri
# jepang : jepang
# bermain : main
# lepas : lepas
# menyerah : serah
# senaknya : senak
# bong : bong
# hebohin : hebohin
# menarik : tarik
# pohon : pohon
# plastik : plastik
# bambu : bambu
# isue : isue
# anjlok : anjlok
# tka : tka
# ilegal : ilegal
# merajalele : merajalele
# nasional : nasional
# mingkem : mingkem
# kapasitas : kapasitas
# tersingung : tersingung
# twiterlaporin : twiterlaporin
# polripaling : polripaling
# ditolakwong : ditolakwong
# deliknya : delik
# manawaktu : manawaktu
# menista : nista
# ku : ku
# seng : seng
# pekok : kok
# pbc : pbc
# bondo : bondo
# cocot : cocot
# sabang : sabang
# meraukekader : meraukekader
# ndewek : ndewek
# wes : wes
# kentean : kentean
# peluru : peluru
# pokoe : pokoe
# iki : iki
# empuk : empuk
# menyerang : serang
# presidenbiasa : presidenbiasa
# mangan : mangan
# zmn : zmn
# saiki : saiki
# tuku : tuku
# lob : lob
# pantat : pantat
# nrocky : nrocky
# gerung : gerung
# profesor : profesor
# laku : laku
# tong : tong
# mempercayai : percaya
# gembel : gembel
# warnet : warnet
# walubi : walubi
# bantai : bantai
# bantu : bantu
# rohingya : rohingya
# siapasiapa : siapasiapa
# entar : entar
# pencitranapalagi : pencitranapalagi
# prabowo : prabowo
# pembrontak : pembrontak
# polisidan : polisidan
# pengadilan : adil
# utuk : utuk
# menegakan : tega
# didukung : dukung
# rakyatjokowi : rakyatjokowi
# resahlengserkan : resahlengserkan
# bapaknya : bapak
# bunuh : bunuh
# balas : balas
# buatkan : buat
# reklamasi : reklamasi
# isueisue : isueisue
# sehubung : hubung
# pemilihan : pilih
# bentuk : bentuk
# jadikan : jadi
# robot : robot
# penyembah : sembah
# alah : alah
# swt : swt
# merintahkan : merintahkan
# perangi : rang
# makar : makar
# polisitakut : polisitakut
# ketololan : tolol
# haq : haq
# ditampilkan : tampil
# menyolot : solot
# diobati : obat
# universitas : universitas
# maungdaw : maungdaw
# sunah : sunah
# berakibat : akibat
# kemiskinan : miskin
# olah : olah
# terjangkau : jangkau
# kebutuhan : butuh
# kesenjangan : senjang
# lebar : lebar
# bengkak : bengkak
# karuan : karuan
# aset : aset
# angota : angota
# tudak : tudak
# digangu : digangu
# kekalahan : kalah
# upaya : upaya
# penghalalan : halal
# oknum : oknum
# rezimrezim : rezimrezim
# berbudaya : budaya
# catet : catet
# korbanya : korbanya
# memeriksa : periksa
# sandi : sandi
# terlibat : libat
# saracen : saracen
# membatalkan : batal
# pengangkatan : angkat
# berlakuser : berlakuser
# kerudung : kerudung
# konfrensi : konfrensi
# pers : pers
# islami : islami
# bwahaha : bwahaha
# menonton : tonton
# stadion : stadion
# bendera : bendera
# nmerah : nmerah
# mberantas : mberantas
# merajalela : rajalela
# bak : bak
# jerman : jerman
# diresmikan : resmi
# wc : wc
# keliling : keliling
# gunting : gunting
# pitanya : pita
# nis : nis
# mensyaratkan : syarat
# berdirinya : diri
# kgb : kgb
# kerjasama : kerjasama
# yahut : yahut
# setuju : tuju
# nekat : nekat
# gorengan : goreng
# jarah : jarah
# warung : warung
# nbonek : nbonek
# jancuknsory : jancuknsory
# rasis : ras
# menahanx : menahanx
# yaelah : yaelah
# mengurusi : urus
# angotadpr : angotadpr
# budek : budek
# iblisintinya : iblisintinya
# ribuan : ribu
# dirugikan : rugi
# belagitu : belagitu
# mochherianto : mochherianto
# hei : hei
# pigai : pigai
# akal : akal
# sehat : sehat
# perut : perut
# tepati : tepat
# rakyatapi : rakyatapi
# kapolri : kapolri
# pensiun : pensiun
# ketegasan : tegas
# memimpin : pimpin
# aduan : adu
# terabaikan : abai
# pekerja : kerja
# tol : tol
# lempar : lempar
# merah : merah
# hormat : hormat
# deportasi : deportasi
# kristen : kristen
# lunklo : lunklo
# sunat : sunat
# sono : sono
# ijazah : ijazah
# tingi : tingi
# bedakan : beda
# permesta : permesta
# semesta : semesta
# fb : fb
# template : template
# antislam : antislam
# dsb : dsb
# berbanding : banding
# lurus : lurus
# bermesran : bermesran
# produsen : produsen
# terbesar : besar
# zionis : zionis
# yahudi : yahudi
# pelacur : lacur
# anurbegini : anurbegini
# mengompori : kompor
# berkeliaran : liar
# bangkai : bangkai
# rajin : rajin
# tarif : tarif
# antikorupsi : antikorupsi
# bubar : bubar
# sentuh : sentuh
# kekuasan : kuas
# wagakbener : wagakbener
# asongan : asong
# kotoran : kotor
# palsu : palsu
# pelacuran : lacur
# viktor : viktor
# beragama : agama
# ngancam : ngancam
# htpstcodxidq : htpstcodxidq
# zqhv : zqhv
# oprohingya : oprohingya
# afghanistan : afghanistan
# didunia : dunia
# banglanjutkanbiar : banglanjutkanbiar
# kampretbani : kampretbani
# kencing : kencing
# onta : onta
# kejang : kejang
# semuax : semuax
# prilaku : prilaku
# seks : seks
# nyimpang : nyimpang
# mui : mui
# perilaku : perilaku
# menyimpang : simpang
# melewati : lewat
# luka : luka
# berkah : berkah
# junmyeonid : junmyeonid
# wtf : wtf
# ðÿ˜‚ :
# idupnya : idupnya
# gabut : gabut
# kasian : kasi
# seniat : niat
# kebenciaâ€¦ : kebencia
# httpstcobfzgh : httpstcobfzgh
# hahahahatimnasnya : hahahahatimnasnya
# loloas : loloas
# ngledekin : ngledekin
# laenmalu : laenmalu
# maludiem : maludiem
# bae : bae
# jamban : jamban
# got : got
# xfxfxxanterima : xfxfxxanterima
# spotify : spotify
# dukungan : dukung
# xfxfxxaxfxfxxa : xfxfxxaxfxfxxa
# spotifyidnnxfxfxxdjakarta : spotifyidnnxfxfxxdjakarta
# plaza : plaza
# indonesianxfxfxxa : indonesianxfxfxxa
# xexxa : xexxa
# bharianmy : bharianmy
# bhsukan : bhsukan
# terbaik : baik
# kejuaraan : juara
# aysar : aysar
# hadi : had
# mohd : mohd
# shapri : shapri
# mengharapkan : harap
# gelaran : gelar
# dimenanginya : menang
# jakartaâ€¦ : jakarta
# aqsejuga : aqsejuga
# penasihat : nasihat
# dpd : dpd
# fpi : fpi
# hamid : hamid
# abdullah : abdullah
# alkaaf : alkaaf
# rombongan : rombong
# jamaâ€™ahnya : jama ahnya
# melintas : lintas
# memimâ€¦ : mim
# cakyono : cakyono
# bolajakarta : bolajakarta
# pertandingan : tanding
# md : md
# backback : backback
# fc : fc
# kaptenâ€¦ : kapten
# jakmania : jakmania
# ciracas : ciracas
# nauval : nauval
# fluppny : fluppny
# namirchocolate : namirchocolate
# areajulid : areajulid
# tuhan : tuhan
# kerjaan : kerja
# kontraktor : kontraktor
# swasta : swasta
# meskâ€¦ : mesk
# httpstconinxwmst : httpstconinxwmst
# julii : juli
# paltiwest : paltiwest
# bernasib : nasib
# lihatlah : lihat
# mampâ€¦ : mamp
# ivan : ivan
# fernanda : fernanda
# ll : ll
# pemuda : pemuda
# karang : karang
# kadempel : kadempel
# theowl : theowl
# menteri : menteri
# pekerjaan : kerja
# perumahan : rumah
# pupr : pupr
# basuki : basuki
# hadimuljono : hadimuljono
# progres : progres
# ratarata : ratarata
# renovasâ€¦ : renovas
# entien : entien
# ajach : ajach
# ðÿ€ :
# kompastv : kompastv
# diguyur : guyur
# deras : deras
# bpbd : bpbd
# catat : catat
# tergenang : genang
# httpstcogbwobwpvd : httpstcogbwobwpvd
# httpstcofhereduvs : httpstcofhereduvs
# âœ‚ :
# ck : ck
# âšœ :
# terkaget : kaget
# mendengar : dengar
# memilih : pilih
# ibunya : ibu
# dibanding : banding
# menghafal : hafal
# kitab : kitab
# terhenyak : henyak
# mendeâ€¦ : mende
# kebaya : kebaya
# nayeon : nayeon
# mnm : mnm
# sign : sign
# pair : pair
# ewo : ewo
# mono : mono
# fol : fol
# jeong : jeong
# unit : unit
# dahyun : dahyun
# jihyoâ€¦ : jihyo
# httpstcoiktihjqc : httpstcoiktihjqc
# silamt : silamt
# after : after
# pleaseâ€‹ : please
# allaja : allaja
# rizmaya : rizmaya
# lindungan : lindung
# dorongan : dorong
# menuntaskanâ€¦ : tuntas
# gayunkroland : gayunkroland
# drainase : drainase
# berfungsi : fungsi
# ratusan : ratus
# terendam : rendam
# wilayah : wilayah
# sejakâ€¦ : sejak
# narasinewsroom : narasinewsroom
# mengundang : undang
# tewasnya : tewas
# brigadir : brigadir
# novriansyah : novriansyah
# yosua : yosua
# hutabarat : hutabarat
# dinas : dinas
# kadiv : kadiv
# ladsah : ladsah
# ferdinandhutah : ferdinandhutah
# gubernurnya : gubernur
# dipermalukan : malu
# cepat : cepat
# berselang : selang
# bbrp : bbrp
# sistemâ€¦ : sistem
# anshar : anshar
# saud : saud
# detalewar : detalewar
# indomielovers : indomielovers
# merantau : rantau
# jakartaorg : jakartaorg
# mie : mie
# sedap : sedap
# dllbahkâ€¦ : dllbahk
# httpstcoxdaxyywxtt : httpstcoxdaxyywxtt
# asifudin : asifudin
# ghotbener : ghotbener
# sibuk : sibuk
# identitas : identitas
# pemimpinâ€¦ : pimpin
# mcaops : mcaops
# kontras : kontras
# baku : baku
# tembak : tembak
# bharada : bharada
# halnya : hal
# kejanggalan : janggal
# kematian : mati
# enam : enam
# laskarâ€¦ : laskar
# azam : azam
# buser : buser
# kadroon : kadroon
# takoyaki : takoyaki
# disitu : situ
# menyelinap : selinap
# hahahhahaha : hahahhahaha
# li : li
# con : con
# wai : wai
# menjabat : jabat
# apbd : apbd
# tertinggi : tinggi
# seluruhâ€¦ : seluruh
# asmaku : asma
# rada : rada
# bebeledagan : bebeledagan
# joie : joie
# apaapa : apaapa
# dimanamanaâ€¦ : dimanamana
# atabdillahtoha : atabdillahtoha
# saifulmujani : saifulmujani
# prof : prof
# saiful : saiful
# menceritakan : cerita
# pengalamannya : alam
# konsultan : konsultan
# politiâ€¦ : politi
# httpstcogztrzzhjy : httpstcogztrzzhjy
# bocaharusbawah : bocaharusbawah
# azq : azq
# ormaslsm : ormaslsm
# dprd : dprd
# disirep : sirep
# dana : dana
# hibah : hibah
# jaâ€¦ : ja
# httpstcoslgfsfwep : httpstcoslgfsfwep
# recehanâ : receh
# gunromli : gunromli
# pamerin : pamerin
# sirkuit : sirkuit
# balapan : balap
# update : update
# daftarnya : daftar
# httpstcoohosâ€¦ : httpstcoohos
# pinangranti : pinangranti
# pr : pr
# direalisasikan : realisasi
# berdampak : dampak
# pusiâ€¦ : pus
# dikirimi : kirim
# karya : karya
# berjudul : judul
# senyumsenyum : senyumsenyum
# pecintanya : cinta
# terima : terima
# uâ€¦ : u
# httpstcocdklmwf : httpstcocdklmwf
# miftah : miftah
# rizaq : rizaq
# txtdaribogor : txtdaribogor
# kereta : kereta
# bogorjakartahati : bogorjakartahati
# daks : daks
# httpstcoosrqrrwpc : httpstcoosrqrrwpc
# colek : colek
# menggunung : gunung
# dipolâ€¦ : pol
# bayu : bayu
# haris : haris
# adriansyahyasin : adriansyahyasin
# desain : desain
# pemenang : menang
# sayembara : sayembara
# stasiun : stasiun
# mrt : mrt
# cakep : cakep
# ðÿ˜ :
# arsitektur : arsitektur
# menyerupai : rupa
# gaâ€¦ : ga
# wðÿ¦‹ : w
# sebaran : sebar
# titik : titik
# peningkatan : tingkat
# wibâ€¦ : wib
# lelaki : lelaki
# timur : timur
# laga : laga
# persahabatan : sahabat
# rans : rans
# nusantara : nusantara
# kemayoran : mayor
# mengamuk : amuk
# httpstcooojtwvjfbc : httpstcooojtwvjfbc
# bolaindocom : bolaindocom
# kumparan : kumpar
# jamaah : jamaah
# air : air
# wib : wib
# total : total
# juan : juan
# sunni : sunni
# mirasasmiita : mirasasmiita
# newnsarinah : newnsarinah
# magnet : magnet
# destinasi : destinasi
# sarinah : sarinah
# dipugar : pugar
# beroperasi : operasi
# telâ€¦ : tel
# juragantajirrr : juragantajirrr
# jumat : jumat
# pagi : pagi
# menyebabkan : sebab
# kepala : kepala
# pusat : pusat
# informasi : informasi
# jakaâ€¦ : jaka
# biqa : biqa
# erick : erick
# thohir : thohir
# proses : proses
# transformasi : transformasi
# detailseriusdan : detailseriusdan
# sungguhsunâ€¦ : sungguhsun
# rezkyibrohim : rezkyibrohim
# lahir : lahir
# komentatorberkelas : komentatorberkelas
# ¡ð :
# ð :
# î¨€ :
# dessyayni : dessyayni
# faye : faye
# nyimasruminah : nyimasruminah
# sengsara : sengsara
# rakyatnya : rakyat
# surut : surut
# aamiin : aamiin
# yra : yra
# httpstcouâ€¦ : httpstcou
# gg : gg
# dihina : hina
# usernameku : usernameku
# mafiawasit : mafiawasit
# comebacknya : comebacknya
# tayangan : tayang
# mitra : mitra
# olahraga : olahraga
# antv : antv
# silahkan : silah
# kirim : kirim
# sms : sms
# dibacakan : baca
# makanâ€¦ : makan
# rendi : rendi
# muhamad : muhamad
# babaalie : babaalie
# menunaikan : tunai
# shalat : shalat
# hijriah : hijriah
# masjid : masjid
# istiqlal : istiqlal
# erickthohir : erickthohir
# bangkitbersamaetâ€¦ : bangkitbersamaet
# ahimcakep : ahimcakep
# habis : habis
# penduduk : duduk
# miskin : miskin
# naik… : naik
# efek : efek
# gotberner : gotberner
# httpâ€¦ : http
# rita : rita
# wati : wati
# exlolina : exlolina
# langganan : langgan
# terpenting : penting
# jis : jis
# formula : formula
# terbaru : baru
# perbaiâ€¦ : perbai
# ruangan : ruang
# persijajkt : persijajkt
# ft : ft
# tothenextlevel : tothenextlevel
# persijaday : persijaday
# believein : believein
# persijajakarta : persijajakarta
# httpstcoufayibuc : httpstcoufayibuc
# prasetiyo : prasetiyo
# nazaruddin : nazaruddin
# hahahaðÿ˜ : hahaha
# ngakak : ngakak
# krjaâ€¦ : krja
# httpstcomlistj : httpstcomlistj
# khadaffi : khadaffi
# bnr : bnr
# surprise : surprise
# johnny : johnny
# tbtb : tbtb
# dikabulkan : kabul
# riekee : riekee
# âœ§ :
# kia : kia
# memori : memori
# perbelanjaan : belanja
# diajak : ajak
# kakek : kakek
# dodomitro : dodomitro
# breakingnews : breakingnews
# dengar : dengar
# pengumuman : umum
# via : via
# toa : toa
# banjirâ€¦ : banjir
# httpstcowjjsltwve : httpstcowjjsltwve
# arief : arief
# imam : imam
# poero : poero
# palilingan : palilingan
# moesa : moesa
# shahab : shahab
# ariestarico : ariestarico
# provinsi : provinsi
# sejahtera : sejahtera
# urus : urus
# lâ€¦ : l
# kom : kom
# catchmeupid : catchmeupid
# cnn : cnn
# detik : detik
# intimidasi : intimidasi
# meliput : liput
# penembakan : tembak
# diterima : terima
# duâ€¦ : du
# vicaa : vicaa
# sdang : sdang
# stress : stress
# nyaiibubu : nyaiibubu
# dipamerin : dipamerin
# ditunjukkin : ditunjukkin
# ðÿ¤¦ :
# httpstcooddgazrki : httpstcooddgazrki
# asuhan : asuh
# kerangkeng : kerangkeng
# suryo : suryo
# tidakâ€¦ : tidak
# httpstcoelrqjonuv : httpstcoelrqjonuv
# vitaavp : vitaavp
# mencekam : cekam
# peristiwa : peristiwa
# kudatuli : kudatuli
# perebutan : rebut
# kantor : kantor
# dpp : dpp
# pdi : pdi
# diponegoro : diponegoro
# melayu : melayu
# ðÿ˜· :
# nulis : nulis
# bio : bio
# penulis : tulis
# menyinggungâ€¦ : singgung
# httpstcozdvokcbsee : httpstcozdvokcbsee
# withlovekeira : withlovekeira
# singosari : singosari
# penelitian : teliti
# ðÿ¥² :
# darion : darion
# gadisresidub : gadisresidub
# omongan : omong
# ok : ok
# httpstcobepvrnxl : httpstcobepvrnxl
# rose : rose
# ðÿ‡·â€œðÿ‡´â€œðÿ‡§â€œðÿ‡§â€œðÿ‡¾â€œ :
# â™ :
# ðÿ‡°â€œðÿ‡ºâ€œðÿ‡²â€œðÿ‡¦â€œðÿ‡¯â€œðÿ‡¦â€œðÿ‡¸â€œ :
# dilanda : landa
# benda : benda
# gubernurâ€¦ : gubernur
# httpstcooswfxbm : httpstcooswfxbm
# rh : rh
# muhammad : muhammad
# ikhsan : ikhsan
# azhar : azhar
# komedian : komedian
# komeng : komeng
# penerimaan : terima
# pengarahan : arah
# perwira : perwira
# tni : tni
# dilantik : lantik
# markas : markas
# ·ð :
# ¸ð :
# ² :
# ¢ð :
# ‚ð :
# ­ð :
# vivabola : vivabola
# jadwal : jadwal
# siaran : siar
# httpstcoakutnyt : httpstcoakutnyt
# î¨€ :
# mawasdir : mawasdir
# azabnya : azab
# jualan : jual
# syahwat : syahwat
# rendy : rendy
# ï€ :
# mbaksri : mbaksri
# dilukai : luka
# even : even
# manapunboleh : manapunboleh
# andil : andil
# batasi : batas
# denganâ€¦ : dengan
# httpstcorwfcpul : httpstcorwfcpul
# rndomfeeds : rndomfeeds
# aesleven : aesleven
# mustahil : mustahil
# kuker : kuker
# base : base
# aespa : aespa
# nabur : nabur
# yaðÿ¥²ðÿ¥²ðÿ¥²ðÿ¥²ðÿ¥² : ya
# ganjarpranowo : ganjarpranowo
# miskinnya : miskin
# adera : adera
# jangmi : jangmi
# puasnya : puas
# alumni : alumni
# mengritik : mengritik
# menjembati : menjembati
# komunikasi : komunikasi
# damai : damai
# kaliâ€¦ : kali
# httpstcohwvhwvqha : httpstcohwvhwvqha
# kemenagri : kemenagri
# asrama : asrama
# jemaah : jemaah
# kloter : kloter
# embarkasi : embarkasi
# jks : jks
# liter : liter
# zamzam : zamzam
# kartu : kartu
# kewaspâ€¦ : kewasp
# bujang : bujang
# inam : inam
# kpn : kpn
# stroke : stroke
# kepalamu : kepala
# httpstcovjpatgdr : httpstcovjpatgdr
# suratan : surat
# tangan : tangan
# menerima : terima
# kondisi : kondisi
# seâ€¦ : se
# httpstconothnvpw : httpstconothnvpw
# ferrywan : ferrywan
# hitung : hitung
# kelahiran : lahir
# httpstcorwyppujvs : httpstcorwyppujvs
# lexiprementre : lexiprementre
# yuliegunawan : yuliegunawan
# prinsip : prinsip
# kedilan : dil
# bid : bid
# diterapkan : terap
# jakartaakses : jakartaakses
# setara : tara
# adil : adil
# memungkinkanâ€¦ : mungkin
# awangsyah : awangsyah
# projectmorg : projectmorg
# perjuangan : juang
# tergabung : gabung
# jaringan : jaring
# melampuai : melampuai
# hakâ€¦ : hak
# serotoninðÿ´ : serotonin
# httpstcoyqizwsxln : httpstcoyqizwsxln
# idn : idn
# times : times
# pria : pria
# ardiansyah : ardiansyah
# hanyut : hanyut
# terseret : seret
# arus : arus
# aliran : alir
# ciliwung : ciliwung
# tebet : tebet
# selatan : selatan
# mencariâ€¦ : cari
# httpstcoutnehy : httpstcoutnehy
# voiid : voiid
# berkeluarga : keluarga
# ortuku : ortuku
# anakanakku : anakanakku
# httpstcocvndzbuij : httpstcocvndzbuij
# kalogistics : kalogistics
# peliharaan : pelihara
# hamster : hamster
# jawa : jawa
# mmmmmmm : mmmmmmm
# sihirsains : sihirsains
# curious : curious
# subconsciously : subconsciously
# kaki : kaki
# asosiasi : asosiasi
# statuâ€¦ : statu
# nl : nl
# sudin : sudin
# barat : barat
# mendistribusikan : distribusi
# bantuan : bantu
# terdampak : dampak
# genangan : genang
# kelurahan : lurah
# jakarâ€¦ : jakar
# httpstcogmjjeqjias : httpstcogmjjeqjias
# maspiyuaja : maspiyuaja
# suriah : suriah
# suriahkan : suriahkan
# dipikiran : pikir
# buzzerp : buzzerp
# pembinaâ€¦ : bina
# httpstcoakaosdhf : httpstcoakaosdhf
# ayahefaiq : ayahefaiq
# lonelyp : lonelyp
# biasaagung : biasaagung
# perbandingan : banding
# area : area
# kebanjiran : banjir
# durasi : durasi
# httpstcomgfuems : httpstcomgfuems
# erlanda : erlanda
# arlan : arlan
# cut : cut
# jeda : jeda
# due : due
# date : date
# hitungan : hitung
# bulat : bulat
# rasanâ€¦ : rasan
# httpstcobgdtsoseu : httpstcobgdtsoseu
# anakmamahpapah : anakmamahpapah
# bb : bb
# bogor : bogor
# nyalon : nyalon
# kemanaa : kemanaa
# ngecat : ngecat
# rambut : rambut
# faiâ€¦ : fai
# httpstcoxrrfpwex : httpstcoxrrfpwex
# giveaway : giveaway
# elvicto : elvicto
# men : men
# skincareðÿ : skincare
# tampakan : tampak
# muâ€¦ : mu
# httpstcobifbuxmx : httpstcobifbuxmx
# pekan : pekan
# hiburan : hibur
# spektakuler : spektakuler
# gratis : gratis
# tampilnya : tampil
# musisi : musisi
# httpstcoizsgffh : httpstcoizsgffh
# ary : ary
# prasetyo : prasetyo
# beasiswa : beasiswa
# imbalan : imbal
# pemprov : pemprov
# mengkampanyekan : kampanye
# kebersihan : bersih
# kawasan : kawasan
# mrâ€¦ : mr
# misbah : misbah
# ù…øµø¨ø§ø­ :
# tujuannya : tuju
# ngeluarin : ngeluarin
# unek : unek
# kerasa : rasa
# ngeganjel : ngeganjel
# otomatisâ€¦ : otomatis
# httpstcowhkqjmybj : httpstcowhkqjmybj
# lilylovely : lilylovely
# marulovinka : marulovinka
# miduk : miduk
# kebanyakanðÿ˜ : banyak
# ichigo : ichigo
# sbmptnfess : sbmptnfess
# malang : malang
# bandunâ€¦ : bandun
# httpstcodznukes : httpstcodznukes
# egaâ²â¹ : ega
# maba : maba
# wawanpapaiko : wawanpapaiko
# point : point
# sekelas : kelas
# nyc : nyc
# aje : aje
# ujan : ujan
# meâ€¦ : me
# httpstcoydandbav : httpstcoydandbav
# ponakan : ponakan
# tom : tom
# cruise : cruise
# transitnya : transit
# ngecek : ngecek
# alternatif : alternatif
# bali : bal
# giladaaah : giladaaah
# harganyaâ€¦ : harga
# httpstcosnygfgybna : httpstcosnygfgybna
# odet : odet
# dwindonesia : dwindonesia
# istilah : istilah
# merujuk : rujuk
# gelombang : gelombang
# yn : yn
# cm : cm
# rmh : rmh
# puri : puri
# kembangan : kembang
# berhenti : henti
# siangâ€¦ : siang
# httpstcomsldomxod : httpstcomsldomxod
# dodirachman : dodirachman
# koreo : koreo
# minp : minp
# ðÿƒ :
# aiissyfa : aiissyfa
# cl : cl
# dtng : dtng
# niatnya : niat
# pingin : pingin
# pijtsesui : pijtsesui
# prtanyaan : prtanyaan
# awaljadi : awaljadi
# seberpa : seberpa
# tanyakanyg : tanyakanyg
# jls : jls
# bdn : bdn
# entanâ€¦ : entan
# ÿð•š :
# ¬ç—ð•ƒï¼¯ :
# ðð :
# ï½á—°ð :
# œð :
# £ð•– :
# semarangpedia : semarangpedia
# dorong : dorong
# kolaborasi : kolaborasi
# sukseskan : sukses
# transisi : transisi
# httpstcoiliobbnc : httpstcoiliobbnc
# httpstconjkeamgxv : httpstconjkeamgxv
# semarangpediacom : semarangpediacom
# dnaddestroyer : dnaddestroyer
# pep : pep
# guardiola : guardiola
# pelatih : latih
# wawaw : wawaw
# eluia : eluia
# brightwin : brightwin
# jodohnya : jodoh
# masmas : masmas
# daaneesh : daaneesh
# winiasta : winiasta
# gawl : gawl
# tibatiba : tibatiba
# dijodohkan : jodoh
# ...
# badmintontalk : badmintontalk
# kodai : koda
# mode : mode
# tipesnya : tipesnya
# reog : reog
# ygy : ygy
# athðÿ¥­ : ath
# songlullaby : songlullaby
# mengurangi : kurang
# abaca : abaca
# cma : cma
# httpstcotvxloiuq : httpstcotvxloiuq
# quantipian : quantipian
# grup : grup
# member : member
# peâ€¦ : pe
# httpstcolpkrxlsf : httpstcolpkrxlsf
# stabucz : stabucz
# bosen : bosen
# stronger : stronger
# believe : believe
# huhuðÿ˜­ðÿ˜­ : huhu
# congraâ€¦ : congra
# tanggadarurat : tanggadarurat
# babydolpinnn : babydolpinnn
# menembuhs : menembuhs
# pertahanan : tahan
# baja : baja
# gigih : gigih
# iniðÿ : ini
# httpstcofsbvqpgya : httpstcofsbvqpgya
# yaya : yaya
# suklisius : suklisius
# oma : oma
# gill : gill
# frustration : frustration
# over : over
# back : back
# emosional : emosional
# karir : karir
# geâ€¦ : ge
# silmaðÿœ¸ : silma
# bulutangkisri : bulutangkisri
# raketnya : raket
# dibanting : banting
# httpstcokebtkc : httpstcokebtkc
# vanila : vanila
# passwordnyyaaa : passwordnyyaaa
# selebrasi : selebrasi
# teremosional : emosional
# match : match
# iniðÿ˜­ðÿ : ini
# congrats : congrats
# thank : thank
# irwansyahâ¤ï¸â€ðÿ : irwansyah
# httpstcoâ€¦ : httpstco
# this : this
# sportstimeid : sportstimeid
# sektor : sektor
# tunggal : tunggal
# kritikan : kritik
# siniðÿ¥º : sini
# pelan : pelan
# membuktikan : bukti
# jadâ€¦ : jad
# farrí› : farr
# ðÿ¸ :
# proud : proud
# ðÿ¤ :
# rewatch : rewatch
# matchnya : matchnya
# lky : lky
# sf : sf
# sgo : sgo
# mastiin : mastiin
# settingan : settingan
# playback : playback
# bukanâ€¦ : bukan
# httpstcoxnkqjnjy : httpstcoxnkqjnjy
# ann : ann
# mardanialisera : mardanialisera
# menyabet : sabet
# singapore : singapore
# atlet : atlet
# selurâ€¦ : selur
# marcellktsr : marcellktsr
# penaikan : naik
# karirnya : karirnya
# ae : ae
# stacy : stacy
# chutlenchen : chutlenchen
# blg : blg
# bergetar : getar
# kebayang : bayang
# pressure : pressure
# httpstcotmtqhcgso : httpstcotmtqhcgso
# sal : sal
# priadi : priadi
# idhamf : idhamf
# ditrial : ditrial
# ancur : ancur
# slurpee : slurpee
# rumahâ : rumah
# httpstcoqbghuulo : httpstcoqbghuulo
# corong : corong
# kehabisan : habis
# diksi : diksi
# menggambarkan : gambar
# realitas : realitas
# httpstcolwhyomozcm : httpstcolwhyomozcm
# selendiipity : selendiipity
# greget : greget
# not : not
# recently : recently
# kejegal : jegal
# mulâ€¦ : mul
# sythnmntiðÿ : sythnmnti
# § :
# ms : ms
# glow : glow
# terdaftarnya : daftar
# merk : merk
# minuman : minum
# terdaftar : daftar
# httpstcomozhijpnq : httpstcomozhijpnq
# apaansi : apaansi
# dftrin : dftrin
# kosmetik : kosmetik
# mkannya : mkannya
# gugatan : gugat
# robybayuw : robybayuw
# duluan : duluan
# déé¥éé¹é : d
# ä±puéêé¹âˆ€ : pu
# harapa : harapa
# basmi : basmi
# maklon : maklon
# diavarass : diavarass
# shock : shock
# sadboy : sadboy
# pengguna : guna
# store : store
# apalah : apa
# prik : prik
# yakali : yakali
# httpstcozgiugtoa : httpstcozgiugtoa
# acha : acha
# ðÿ­ðÿ¤âœ¨ :
# anjj : anjj
# regiii : regiii
# ðÿ³ :
# taunya : tau
# cerita : cerita
# pakenya : pakenya
# bergizi : gizi
# hipohan : hipohan
# pumada : pumada
# lokal : lokal
# puma : puma
# pierre : pierre
# cardin : cardin
# susana : susana
# handayani : handayani
# cacaputrisntka : cacaputrisntka
# dagang : dagang
# mendaftarkan : daftar
# namatanda : namatanda
# putu : putu
# edgar : edgar
# tanaya : tanaya
# playing : playing
# victim : victim
# ðÿ˜† :
# cycy : cycy
# yektiari : yektiari
# moncoeurie : moncoeurie
# euphoriaancal : euphoriaancal
# ohmybeautybank : ohmybeautybank
# skincare : skincare
# ï‡ :
# dsekarlangit : dsekarlangit
# glowbaru : glowbaru
# menggunggataneh : menggunggataneh
# bermukaâ€¦ : muka
# ruslan : ruslan
# gasang : gasang
# duluann : duluann
# gp : gp
# nerima : nerima
# keuntungan : untung
# pemakai : pakai
# skinâ€¦ : skin
# httpstcorsqjrats : httpstcorsqjrats
# ayoe : ayoe
# gapake : gapake
# ksl : ksl
# dindesp : dindesp
# ngaku : ngaku
# httpstcotguebta : httpstcotguebta
# mahayasa : mahayasa
# vivacoid : vivacoid
# setau : tau
# kenal : kenal
# choirul : choirul
# anam : anam
# lagipun : lagi
# bara : bara
# ntah : ntah
# perskincarean : perskincarean
# dontcare : dontcare
# samaâ€¦ : sama
# httpstcosmerxnive : httpstcosmerxnive
# ceritanya : cerita
# msglowfirstsavemsglow : msglowfirstsavemsglow
# httpstcompbityfkj : httpstcompbityfkj
# azzahra : azzahra
# cilorconnoistre : cilorconnoistre
# plot : plot
# twist : twist
# owner : owner
# project : project
# gintoki : gintoki
# txtdrimedia : txtdrimedia
# mendaftar : daftar
# httpstcocdabr : httpstcocdabr
# alfian : alfian
# samudra : samudra
# kelarâ² : kelar
# rebranding : rebranding
# pms : pms
# anakkentank : anakkentank
# donkyahh : donkyahh
# ðÿ¤§ :
# httpstcodspeubtq : httpstcodspeubtq
# feeya : feeya
# beritaberita : beritaberita
# direktorat : direktorat
# jenderal : jenderal
# kekayaan : kaya
# tahunâ€¦ : tahun
# httpstcoaqhelkyn : httpstcoaqhelkyn
# saimomlgraya : saimomlgraya
# kuatkuatan : kuatkuatan
# fulus : fulus
# bisaâ€¦ : bisa
# ù‹ù‹ :
# keknya : kek
# msglow : msglow
# ngakuâ² : ngaku
# diusut : usut
# savemsglow : savemsglow
# laudia : laudia
# kakak : kakak
# ktanya : ktanya
# amanâ² : aman
# fucek : fucek
# podiumbyplus : podiumbyplus
# invasi : invasi
# motorsport : motorsport
# rayðÿœž : ray
# asumsico : asumsico
# disengketain : disengketain
# yaaa : yaaa
# plagiat : plagiat
# kocaksavemsglow : kocaksavemsglow
# cia : cia
# winnerwave : winnerwave
# hatihati : hatihati
# rekayasa : rekayasa
# institusi : institusi
# kepâ€¦ : kep
# owe : owe
# keluarga : keluarga
# peti : peti
# httpstcowazwahfws : httpstcowazwahfws
# ophix : ophix
# hoki : hoki
# cium : cium
# kebohongan : bohong
# httpstcovxâ€¦ : httpstcovx
# edwarfeggy : edwarfeggy
# bostemlen : bostemlen
# hmmm : hmmm
# diperiksa : periksa
# gtu : gtu
# mengecewakan : kecewa
# langsungâ€¦ : langsung
# indragiri : indragiri
# frdmlnd : frdmlnd
# beradab : adab
# turunkanrajaâ€¦ : turunkanraja
# paeran : paeran
# paidi : paidi
# listyo : listyo
# sigit : sigit
# maklumin : maklumin
# terâ€¦ : ter
# httpstcojbegfkuf : httpstcojbegfkuf
# yunankingstar : yunankingstar
# thread : thread
# ×¢ö´×žö¸ö¼× :
# ×•ö¼×öµ×œ :
# ibnxine : ibnxine
# sopir : sopir
# melecehkan : leceh
# komandan : komandan
# dâ€¦ : d
# beby : beby
# jusnic : jusnic
# putrisakera : putrisakera
# otopsi : otopsi
# pasâ€¦ : pas
# httpstconyclxxebew : httpstconyclxxebew
# paklubis : paklubis
# abuwaras : abuwaras
# lilin : lilin
# dihadang : dihadang
# berharap : harap
# ahoker : ahoker
# biasâ€¦ : bias
# omjengkol : omjengkol
# penonaktifan : nonaktif
# dipandang : pandang
# transparansi : transparansi
# pengusutan : usut
# brigadirâ€¦ : brigadir
# httpstcoixowaf : httpstcoixowaf
# warta : warta
# mandailing : mandailing
# bengis : bengis
# sadis : sadis
# jasad : jasad
# mengenaskan : enas
# aksialfatih : aksialfatih
# cybsquad : cybsquad
# ditembak : tembak
# propam : propam
# ferdy : ferdy
# sambo : sambo
# investâ€¦ : invest
# pengacara : acara
# tubuh : tubuh
# dijahit : jahit
# httpstcochemls : httpstcochemls
# beritasatu : beritasatu
# httpstcotlocqizr : httpstcotlocqizr
# ken : ken
# arok : arok
# waaaahhhhhhhhhhhhhh : waaaahhhhhhhhhhhhhh
# mengganggu : ganggu
# profesionalisme : profesionalisme
# httpstcootjtgxm : httpstcootjtgxm
# sahsa : sahsa
# terkuak : kuak
# ferdi : ferdi
# adik : adik
# httpstcokbrnehpya : httpstcokbrnehpya
# httpstcoznbetkct : httpstcoznbetkct
# ù :
# ø§ :
# ø§ù :
# ù‡ :
# ù…ø­ù…ø¯ :
# ø±ø³ùˆù :
# bennyharmanid : bennyharmanid
# kedatangan : datang
# bandara : bandara
# keberadaan : ada
# milik : milik
# idntimes : idntimes
# kamaruddin : kamaruddin
# simanjuntak : simanjuntak
# atensi : atensi
# mendesak : desak
# jendral : jendral
# pol : pol
# jubir : jubir
# fadillah : fadil
# terkesan : kes
# negaraâ : negara
# komunisâ€¦ : komunis
# mbak : mbak
# rara : rara
# terkena : kena
# santet : santet
# kesurupan : surup
# httpstconnsmnjbl : httpstconnsmnjbl
# lordsakto : lordsakto
# bedanya : beda
# alat : alat
# congor : congor
# margani : margani
# menyingkap : singkap
# tabir : tabir
# kristian : kristian
# rinaldo : rinaldo
# mantengin : mantengin
# justice : justice
# almarhum : almarhum
# httpstcohdsunwqmt : httpstcohdsunwqmt
# jaaa : jaaa
# cermati : cermat
# datadata : datadata
# httpstcoyjntvxjgn : httpstcoyjntvxjgn
# tangisan : tangis
# vera : vera
# kekasih : kasih
# httpstcomeqwiak : httpstcomeqwiak
# lai : lai
# alm : alm
# ngeri : ngeri
# secepetnya : secepetnya
# httpstcovqxygorm : httpstcovqxygorm
# kamilia : kamilia
# zahra : zahra
# tanmarm : tanmarm
# ðÿ™ :
# ðÿ‡²ðÿ‡¨ùø±ù :
# ùšùˆù† :
# øªø±ùšøºù†ðÿ‡µðÿ‡¸ :
# jackpakuan : jackpakuan
# he : he
# dihabisi : habis
# otk : otk
# ulah : ulah
# clamitanakhirnya : clamitanakhirnya
# terjd : terjd
# tragedi : tragedi
# pempek : pempek
# kasat : kasat
# penyelidikan : lidi
# transparan : transparan
# httpstcolhpu : httpstcolhpu
# orsina : orsina
# turnip : turnip
# pelitakininews : pelitakininews
# pangkat : pangkat
# kombes : kombes
# marahmarah : marahmarah
# pelcehn : pelcehn
# irjen : irjen
# httpstcocqvvsjâ€¦ : httpstcocqvvsj
# mrbekalicky : mrbekalicky
# samboâ€¦ : sambo
# iateam : iateam
# terbongkarâ€¼ï¸ : bongkar
# httpstcokwuifgmshs : httpstcokwuifgmshs
# kangadangteaii : kangadangteaii
# terawang : terawang
# ngobrol : ngobrol
# roh : roh
# httpstcokuwnpanv : httpstcokuwnpanv
# httpstcozpvqzmvrbr : httpstcozpvqzmvrbr
# sebelasduabelas : sebelasduabelas
# calon : calon
# unilubis : unilubis
# tkp : tkp
# singgah : singgah
# persisnya : persis
# lukaluka : lukaluka
# udateteâ€¦ : udatete
# ñá´‡á´¡éªé´á´… :
# kesurupanelo : kesurupanelo
# sarap : sarap
# menk : menk
# black : black
# maafkaâ€¦ : maafka
# httpstcoeeqtjtpb : httpstcoeeqtjtpb
# aprill : aprill
# ur : ur
# diblock : diblock
# kominfo : kominfo
# segenap : segenap
# httpstcoyzvhgjlbf : httpstcoyzvhgjlbf
# forverotonad : forverotonad
# ezash : ezash
# mengenal : kenal
# ges : ges
# xhraà­§â¤âƒðÿ¦§ : xhra
# tbzdayz : tbzdayz
# sebarin : sebarin
# de : de
# jawafess : jawafess
# lur : lur
# wae : wae
# jenenge : jenenge
# dadi : dadi
# kementrian : tri
# kat : kat
# mbien : mbien
# gaweane : gaweane
# gur : gur
# ngancem : ngancem
# nothingtosay : nothingtosay
# zendagondrong : zendagondrong
# baginda : baginda
# situs : situs
# porno : porno
# ðÿ• :
# sido : sido
# ora : ora
# apk : apk
# ne : ne
# httpstcoomsttybqj : httpstcoomsttybqj
# udin : udin
# racing : racing
# relyourbae : relyourbae
# sambat : sambat
# kertas : kertas
# binder : binder
# ojo : ojo
# neyy : neyy
# ppp : ppp
# yaaðÿ˜ : yaa
# sywa : sywa
# umâ²â² : um
# edmar : edmar
# life : life
# padaâ€¦ : pada
# httpstcopgmefr : httpstcopgmefr
# huhuhu : huhuhu
# ocidd : ocidd
# wlpun : wlpun
# ngechat : ngechat
# ð™žð™ð™šð™£ :
# user : user
# wa : wa
# bntr : bntr
# httpstcoibslunac : httpstcoibslunac
# piraaaa : piraaaa
# jakeekylee : jakeekylee
# httpstcoudfvubmpd : httpstcoudfvubmpd
# kinda : kinda
# iaðÿœ : ia
# tpwk : tpwk
# deadline : deadline
# pendaftaran : daftar
# pse : pse
# google : google
# instagram : instagram
# httpstcoichvavuy : httpstcoichvavuy
# gimanagoogle : gimanagoogle
# buanyakkk : buanyakkk
# pejuang : juang
# retjeh : retjeh
# ngantemi : ngantemi
# bnrn : bnrn
# httpstcoogsramwvkb : httpstcoogsramwvkb
# raa : raa
# saâ­ : sa
# julianmj : julianmj
# blockâ€¦ : block
# wulaaaan : wulaaaan
# dnfifar : dnfifar
# petisi : petisi
# pecat : pecat
# boomer : boomer
# pandu : pandu
# sasiiii : sasiiii
# terupdet : terupdet
# beritaâ€¦ : berita
# mee : mee
# ainunrozi : ainunrozi
# kaaaaa : kaaaaa
# rossantoy : rossantoy
# dikonsumsi : konsumsi
# didaftarin : didaftarin
# diblok : blok
# daftarâ€¦ : daftar
# httpstcolruyqwmbc : httpstcolruyqwmbc
# ãƒ‡ãƒãƒˆ :
# grahamasscot : grahamasscot
# nahhhh : nahhhh
# mail : mail
# gmailðÿ˜…gendenk : gmail gendenk
# akidoverseas : akidoverseas
# blokiran : blokir
# whatsfun : whatsfun
# dream : dream
# me : me
# keep : keep
# safe : safe
# kittenjihan : kittenjihan
# akiheyyyyyyy : akiheyyyyyyy
# kepengen : ken
# nyatakan : nyata
# protesnetizen : protesnetizen
# regulasi : regulasi
# menâ€¦ : men
# berryâ°barry : berry barry
# bayknight : bayknight
# resir : resir
# nden : nden
# jawabannya : jawab
# mekaâ€¦ : meka
# donatcucuk : donatcucuk
# kemiskinanku : miskin
# cimeng : cimeng
# {'feiitoteles': 'feiitoteles', 'pinguin': 'pinguin', 'tolol': 'tolol', 'ðÿ™†ðÿ\x8f¿â€\x8dâ™‚ï¸\x8f': '', 'idextratime': 'idextratime', 'emang': 'emang', 'viet': 'viet', 'thai': 'thai', 'jiahelahlu': 'jiahelahlu', 'aduh': 'aduh', 'kesel': 'kesel', 'banget': 'banget', 'httpstcoghnepktku': 'httpstcoghnepktku', 'devy': 'devy', 'hayatalfatih': 'hayatalfatih', 'detikcom': 'detikcom', 'bestie': 'bestie', 'bocor': 'bocor', 'curhat': 'curhat', 'blm': 'blm', 'tntg': 'tntg', 'suami': 'suami', 'org': 'org', 'faedah': 'faedah', 'nyaapa': 'nyaapa', 'bâ€¦': 'b', 'susan': 'sus', 'amelia': 'amelia', 'dasar': 'dasar', 'nyakitin': 'nyakitin', 'mulu': 'mulu', 'lo': 'lo', 'bangsat': 'bangsat', 'gaguna': 'gaguna', 'bgt': 'bgt', 'ðÿœœ': '', 'mingdep': 'mingdep', 'uas': 'uas', 'nambahin': 'nambahin', 'pikiran': 'pikir', 'mo': 'mo', 'bilang': 'bilang', 'kek': 'kek', 'elah': 'elah', 'nungâ€¦': 'nung', 'httpstcoacoytiibh': 'httpstcoacoytiibh', 'flo': 'flo', 'koalakoalu': 'koalakoalu', 'maen': 'maen', 'ml': 'ml', 'bego': 'bego', 'yak': 'yak', 'tautaupuyeng': 'tautaupuyeng', 'nadirs': 'nadirs', 'andinimaharan': 'andinimaharan', 'ngajinya': 'ngajinya', 'ustad': 'ustad', 'mosok': 'mosok', 'menebar': 'tebar', 'kebencian': 'benci', 'orang': 'orang', 'wafat': 'wafat', 'ajaran': 'ajar', 'andâ€¦': 'and', 'gua': 'gua', 'dapet': 'dapet', 'kelas': 'kelas', 'isinya': 'isi', 'anak': 'anak', 'pemales': 'pales', 'mageran': 'mageran', 'nolep': 'nolep', 'diaâ€¦': 'dia', 'httpstcokbbmta': 'httpstcokbbmta', 'ainiqrâ²â\x81µ': 'ainiqr', 'dipelihara': 'pelihara', 'dikembangin': 'dikembangin', 'pulanael': 'pulanael', 'blackpinkfam': 'blackpinkfam', 'uh': 'uh', 'pantesan': 'pantesan', 'pas': 'pas', 'ngeqrt': 'ngeqrt', 'jokes': 'jokes', 'gw': 'gw', 'ih': 'ih', 'kontol': 'kontol', 'bet': 'bet', 'ø˜ð': '', '“': '', '…': '', 'benernya': 'benernya', 'bersyukur': 'syukur', 'dika': 'dika', 'please': 'please', 'tololpradika': 'tololpradika', 'mukaikhlas': 'mukaikhlas', 'manusia': 'manusia', 'bumi': 'bumi', 'duit': 'duit', 'kecuali': 'kecuali', 'gimana': 'gimana', 'romitsut': 'romitsut', 'menghina': 'hina', 'fitnah': 'fitnah', 'pembenci': 'benci', 'ulama': 'ulama', 'kecam': 'kecam', 'uang': 'uang', 'puluhan': 'puluh', 'juta': 'juta', 'namanya': 'nama', 'akâ€¦sensor': 'ak sensor', 'repðÿ': 'rep', '’': '', '‹eblik': 'eblik', 'pglliard': 'pglliard', 'naufalss': 'naufalss', 'mlbbfess': 'mlbbfess', 'liat': 'liat', 'natan': 'natan', 'mati': 'mati', 'segitunatalia': 'segitunatalia', 'kill': 'kill', 'tertinggimaksud': 'tertinggimaksud', 'kakanya': 'kakanya', 'tanknya': 'tank', 'tolâ€¦': 'tol', 'httpstcoocfyigkazuhas': 'httpstcoocfyigkazuhas', 'tolong': 'tolong', 'stop': 'stop', 'gue': 'gue', 'nonton': 'nonton', 'tebakan': 'tebak', 'yt': 'yt', 'sugar': 'sugar', 'juwimauniverse': 'juwimauniverse', 'konyol': 'konyol', 'kwkwwkkw': 'kwkwwkkw', 'tololhatta': 'tololhatta', 'tujuan': 'tuju', 'kyk': 'kyk', 'gt': 'gt', 'anjir': 'anjir', 'nge': 'nge', 'hate': 'hate', 'pake': 'pake', 'nama': 'nama', 'bs': 'bs', 'ngebuat': 'ngebuat', 'bsâ€¦': 'bs', 'guesxwho': 'guesxwho', 'mandi': 'mandi', 'malem': 'malem', 'bikin': 'bikin', 'rematik': 'rematik', 'nyet': 'nyet', 'bintang': 'bintang', 'hahahahahahahahahahaa': 'hahahahahahahahahahaa', 'sepakbola': 'sepakbola', 'gajah': 'gajah', 'kalah': 'kalah', 'elvan': 'elvan', 'sesshomaru': 'sesshomaru', 'but': 'but', 'koga': 'koga', 'aaaaaa': 'aaaaaa', 'bucin': 'bucin', 'and': 'and', 'cute': 'cute', 'ketimbang': 'ketimbang', 'inuyasha': 'inuyasha', 'muter': 'muter', 'lagu': 'lagu', 'glimpse': 'glimpse', 'oâ€¦': 'o', 'knp': 'knp', 'persatu': 'satu', 'hilang': 'hilang', 'dr': 'dr', 'hidup': 'hidup', 'hp': 'hp', 'kmrn': 'kmrn', 'ilang': 'ilang', 'otomatis': 'otomatis', 'foto': 'foto', 'data': 'data', 'all': 'all', 'of': 'of', 'those': 'those', 'memorieâ€¦': 'memorie', 'opulevi': 'opulevi', 'andirozidan': 'andirozidan', 'cfbayern': 'cfbayern', 'falk': 'falk', 'jurnalis': 'jurnalis', 'tier': 'tier', 'dik': 'dik', 'avprodite': 'avprodite', 'convomf': 'convomf', 'adek': 'adek',  ...
# -------------------
# Pandas Apply:   0%|          | 0/1129 [00:00<?, ?it/s]
# 0                         [feiitoteles, pinguin, tolol, ]
# 1       [idextratime, tolol, emang, viet, thai, jiahel...
# 2       [aduh, tolol, emang, kesel, banget, httpstcogh...
# 3       [hayatalfatih, detikcom, bestie, bocor, curhat...
# 4       [dasar, tolol, nyakitin, mulu, lo, bangsat, ga...
#                               ...
# 1124    [grahamasscot, nahhhh, mail, gmail gendenk, pe...
# 1125    [akidoverseas, gw, takut, blokir, kominfo, gw,...
# 1126    [kittenjihan, akiheyyyyyyy, convomf, ken, jadi...
# 1127    [bayknight, resir, nden, gabisa, ngasi, solusi...
# 1128        [hi, kominfo, tolong, blokir, miskin, cimeng]
# Name: text_tokens_stemmed, Length: 1129, dtype: object

# %%
data.to_csv("hasil preprop.csv")

# %% [markdown]
# TF IDF

# %%
from sklearn.feature_extraction.text  import CountVectorizer, TfidfTransformer
#library untuk menghitung menjadi representasi tf atau tf-idf yang dinormalisasi.

# %%
Ulasan = data['text']

# %%
#untuk menghitung jumlah kata yang telah di stemming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 7257

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutan abjad kata dan kemunculan kata nya
# Out:
# {'rt': 5749,
#  'feiitoteles': 1848,
#  'pinguin': 5346,
#  'lu': 3823,
#  'yang': 7118,
#  'tolol': 6719,
#  'ðÿ': 7224,
#  'idextratime': 2720,
#  'emang': 1746,
#  'viet': 6949,
#  'sama': 5806,
#  'thai': 6636,
#  'jiahelahlu': 2991,
#  'aduh': 55,
#  'si': 6099,
#  'kesel': 3388,
#  'banget': 537,
#  'httpstcoghnepktku': 2382,
#  'devy': 1347,
#  'hayatalfatih': 2204,
#  'detikcom': 1346,
#  'terus': 6615,
#  'bestie': 821,
#  'bocor': 910,
#  'kan': 3133,
#  'curhat': 1226,
#  'dia': 1356,
#  'yg': 7130,
#  'blm': 885,
#  'tentu': 6525,
#  'jg': 2989,
#  'tntg': 6705,
#  'suami': 6289,
#  'org': 4950,
#  'itu': 2852,
#  'apa': 299,
#  'faedah': 1816,
#  'nyaapa': 4846,
#  'bâ': 1051,
#  'susan': 6367,
#  'amelia': 203,
#  'dasar': 1285,
#  'nyakitin': 4851,
#  'mulu': 4492,
#  'lo': 3798,
#  'bangsat': 557,
#  'gaguna': 1918,
#  'bgt': 829,
#  'diri': 1536,
#  'ini': 2798,
#  'ðÿœœ': 7228,
#  'mingdep': 4365,
#  'uas': 6840,
#  'malah': 3906,
#  'nambahin': 4565,
#  'pikiran': 5338,
#  'aja': 110,
#  'klo': 3470,
#  'mo': 4407,
#  'buat': 979,
#  'waktu': 6987,
#  'lama': 3672,
#  'bilang': 857,
#  'dulu': 1690,
#  'kek': 3276,
#  'elah': 1733,
#  'nungâ': 4837,
#  'httpstcoacoytiibh': 2298,
#  'flo': 1873,
#  'koalakoalu': 3481,
#  'maen': 3864,
#  'ml': 4395,
#  'bego': 655,
#  'yak': 7112,
#  'tautaupuyeng': 6470,
#  'nadirs': 4542,
#  'anda': 224,
#  'andinimaharan': 230,
#  'ngajinya': 4657,
#  'ustad': 6912,
#  'siapa': 6107,
#  'sih': 6127,
#  'mosok': 4446,
#  'menebar': 4170,
#  'kebencian': 3212,
#  'pada': 4978,
#  'orang': 4945,
#  'wafat': 6975,
#  'ajaran': 114,
#  'dari': 1281,
#  'andâ': 234,
#  'kenapa': 3338,
#  'gua': 2092,
#  'selalu': 5965,
#  'dapet': 1278,
#  'kelas': 3295,
#  'isinya': 2834,
#  'banyak': 572,
#  'anak': 213,
#  'pemales': 5126,
#  'mageran': 3869,
#  'nolep': 4783,
#  'ga': 1907,
#  'bisa': 873,
#  'diaâ': 1370,
#  'httpstcokbbmta': 2423,
#  'ainiqrâ²â': 104,
#  'kok': 3488,
#  'dipelihara': 1509,
#  'dikembangin': 1454,
#  'pulanael': 5515,
#  'blackpinkfam': 880,
#  'uh': 6855,
#  'pantesan': 5039,
#  'pas': 5058,
#  'ngeqrt': 4698,
#  'jokes': 3023,
#  'gw': 2115,
#  'ih': 2734,
#  'kontol': 3536,
#  'bet': 822,
#  'tapi': 6454,
#  'ada': 31,
#  'benernya': 696,
#  'juga': 3043,
#  'harusnya': 2191,
#  'bersyukur': 802,
#  'ya': 7097,
#  'dika': 1448,
#  'please': 5367,
#  'jadi': 2870,
#  'tololpradika': 6722,
#  'mukaikhlas': 4484,
#  'manusia': 3953,
#  'di': 1355,
#  'bumi': 1014,
#  'punya': 5526,
#  'duit': 1685,
#  'kecuali': 3238,
#  'gimana': 2018,
#  'romitsut': 5735,
#  'menghina': 4222,
#  'fitnah': 1870,
#  'dan': 1269,
#  'pembenci': 5129,
#  'ulama': 6867,
#  'bukannya': 1003,
#  'kecam': 3231,
#  'beri': 751,
#  'uang': 6838,
#  'puluhan': 5518,
#  'juta': 3072,
#  'namanya': 4562,
#  'akâ': 146,
#  'sensor': 6022,
#  'repðÿ': 5669,
#  'eblik': 1710,
#  'pglliard': 5324,
#  'naufalss': 4601,
#  'mlbbfess': 4397,
#  'liat': 3751,
#  'natan': 4596,
#  'mati': 4004,
#  'segitunatalia': 5931,
#  'kill': 3446,
#  'tertinggimaksud': 6609,
#  'kakanya': 3105,
#  'tanknya': 6446,
#  'tolâ': 6726,
#  'httpstcoocfyigkazuhas': 2503,
#  'tolong': 6724,
#  'stop': 6277,
#  'gue': 2099,
#  'gak': 1924,
#  'nonton': 4813,
#  'tebakan': 6484,
#  'yt': 7147,
#  'sugar': 6307,
#  'juwimauniverse': 3075,
#  'konyol': 3540,
#  'kwkwwkkw': 3630,
#  'tololhatta': 6721,
#  'tujuan': 6796,
#  'mereka': 4316,
#  'kyk': 3635,
#  'gt': 2089,
#  'anjir': 265,
#  'nge': 4676,
#  'hate': 2196,
#  'lain': 3659,
#  'pake': 4992,
#  'nama': 4561,
#  'bs': 973,
#  'lagi': 3645,
#  'ngebuat': 4679,
#  'bsâ': 974,
#  'guesxwho': 2100,
#  'mandi': 3936,
#  'malem': 3913,
#  'bikin': 855,
#  'rematik': 5655,
#  'nyet': 4878,
#  'bintang': 868,
#  'hahahahahahahahahahaa': 2137,
#  'sepakbola': 6030,
#  'gajah': 1920,
#  'kalah': 3110,
#  'semua': 6003,
#  'elvan': 1742,
#  'kalau': 3111,
#  'sesshomaru': 6056,
#  'pasti': 5066,
#  'but': 1036,
#  'koga': 3486,
#  'aaaaaa': 1,
#  'bucin': 986,
#  'and': 223,
#  'cute': 1230,
#  'ketimbang': 3413,
#  'inuyasha': 2821,
#  'muter': 4524,
#  'lagu': 3651,
#  'glimpse': 2036,
#  'oâ': 4974,
#  'knp': 3477,
#  'satu': 5857,
#  'persatu': 5282,
#  'mulai': 4488,
#  'hilang': 2242,
#  'dr': 1660,
#  'hidup': 2235,
#  'hp': 2274,
#  'kmrn': 3475,
#  'ilang': 2751,
#  'otomatis': 4963,
#  'foto': 1880,
#  'data': 1287,
#  'all': 176,
#  'of': 4892,
#  'those': 6653,
#  'memorieâ': 4117,
#  'opulevi': 4943,
#  'andirozidan': 231,
#  'cfbayern': 1119,
#  'falk': 1827,
#  'termasuk': 6589,
#  'jurnalis': 3068,
#  'tier': 6664,
#  'tinggi': 6683,
#  'dik': 1447,
#  'avprodite': 425,
#  'convomf': 1204,
#  'adek': 38,
#  'nder': 4613,
#  'kadang': 3087,
#  'polos': 5403,
#  'zeinclnya': 7171,
#  'minimal': 4369,
#  'sblm': 5867,
#  'ngeblok': 4678,
#  'kontak': 3532,
#  'utangnya': 6919,
#  'dilunasin': 1481,
#  'lah': 3653,
#  'njirrr': 4772,
#  'dibawa': 1380,
#  'sampe': 5819,
#  'ke': 3199,
#  'alam': 150,
#  'kubur': 3600,
#  'aduhhhhh': 57,
#  'dimeja': 1488,
#  'regis': 5645,
#  'udh': 6849,
#  'kaya': 3190,
#  'grgr': 2085,
#  'psantoda': 5492,
#  'ramlirizal': 5598,
#  'trus': 6777,
#  'mecat': 4032,
#  'kerja': 3374,
#  'pablo': 4976,
#  'gilberto': 2014,
#  'democrazymedia': 1319,
#  'lembaga': 3720,
#  'survey': 6363,
#  'atau': 406,
#  'dibilang': 1389,
#  'kuliah': 3608,
#  'tidak': 6660,
#  'keterlaluanâ': 3410,
#  'httpstcoxujqqslpy': 2645,
#  'endra': 1761,
#  'purnama': 5531,
#  'jangan': 2919,
#  'bocil': 909,
#  'kemarin': 3318,
#  'sore': 6236,
#  'gaada': 1908,
#  'masalah': 3981,
#  'caricari': 1085,
#  'rabbit': 5556,
#  'marquez': 3970,
#  'pengakuan': 5178,
#  'santriwati': 5836,
#  'korban': 3546,
#  'pencabulan': 5151,
#  'kyai': 3634,
#  'jombang': 3029,
#  'jatim': 2935,
#  'mas': 3976,
#  'bechi': 640,
#  'msat': 4460,
#  'ilmu': 2755,
#  'metafakta': 4338,
#  'httpstcowsdmâ': 2632,
#  'warga': 6997,
#  'perempuan': 5256,
#  'bergerak': 744,
#  'realadhidompu': 5630,
#  'ketekberbau': 3405,
#  'mpraldo': 4451,
#  'daneilfrans': 1272,
#  'astaga': 394,
#  'mahami': 3875,
#  'bahasa': 502,
#  'sederhana': 5918,
#  'mampu': 3923,
#  'babehâ': 466,
#  'httpstcobadldvxdb': 2306,
#  'sifat': 6121,
#  'benci': 686,
#  'pd': 5078,
#  'adl': 50,
#  'manusiawi': 3955,
#  'jk': 3007,
#  'tokoh': 6714,
#  'influensergolongankelompok': 2787,
#  'organisasi': 4951,
#  'bhkan': 834,
#  'temâ': 6514,
#  'httpstcorgfxnwzmy': 2552,
#  'partaisocmed': 5053,
#  'faktanya': 1826,
#  'berani': 712,
#  'melapor': 4057,
#  'cuma': 1222,
#  'beberapa': 636,
#  'saja': 5792,
#  'sebab': 5884,
#  'diteror': 1580,
#  'secara': 5912,
#  'fisik': 1869,
#  'maupun': 4013,
#  'psikisâ': 5494,
#  'gedek': 1975,
#  'tetanggaâ²': 6622,
#  'sering': 6045,
#  'pasukan': 5068,
#  'ibuâ²': 2713,
#  'ngerumpi': 4707,
#  'bacotnya': 479,
#  'gede': 1973,
#  'kedengeran': 3240,
#  'jelasâ': 2967,
#  'httpstcotlrafvgoi': 2578,
#  'sya': 6378,
#  'jonruahginting': 3033,
#  'menyamakan': 4287,
#  'pengeroyokan': 5186,
#  'pak': 4988,
#  'ade': 37,
#  'armando': 352,
#  'dgn': 1351,
#  'tindakan': 6681,
#  'aparat': 310,
#  'kepolisian': 3359,
#  'merontokkan': 4326,
#  'giâ': 2032,
#  'saat': 5773,
#  'sangat': 5828,
#  'panik': 5030,
#  'karena': 3152,
#  'kasus': 3172,
#  'hukum': 2689,
#  'kejahatan': 3260,
#  'seksual': 5963,
#  'sedang': 5915,
#  'dihadapi': 1426,
#  'sehingga': 5935,
#  'out': 4968,
#  'meminta': 4113,
#  'seluruâ': 5982,
#  'inra': 2805,
#  'kalo': 3117,
#  'hubungannya': 2683,
#  'ama': 191,
#  'pendidikan': 5167,
#  'komen': 3494,
#  'bagus': 498,
#  'postingan': 5415,
#  'igâ': 2733,
#  'httpstcobjvqpbocp': 2313,
#  'simulakra': 6148,
#  'sini': 6160,
#  'dilihat': 1477,
#  'jelas': 2965,
#  'komitmen': 3499,
#  'pemerintah': 5136,
#  'baca': 473,
#  'ring': 5710,
#  'rezim': 5689,
#  'dalam': 1262,
#  'menuntaskan': 4279,
#  'rantai': 5601,
#  'ks': 3589,
#  'lingkunâ': 3772,
#  'httpstcotkfpyocp': 2576,
#  'llakiuny': 3794,
#  'mari': 3965,
#  'bersama': 792,
#  'kawal': 3185,
#  'kekerasan': 3283,
#  'sex': 6078,
#  'santri': 5835,
#  'oleh': 4912,
#  'httpstcovvcvwcpjl': 2619,
#  'ika': 2739,
#  'jatnika': 2936,
#  'mentrinya': 4271,
#  'begitupun': 654,
#  'presidennya': 5436,
#  'emet': 1749,
#  'koncret': 3514,
#  'natgdisdesa': 4598,
#  'beneran': 691,
#  'nyerahkan': 4875,
#  'nat': 4593,
#  'uyokback': 6927,
#  'cebong': 1097,
#  'otak': 4959,
#  'sungsang': 6339,
#  'solusi': 6225,
#  'alanaangis': 153,
#  'bocah': 906,
#  'borax': 943,
#  'bruno': 972,
#  'mars': 3971,
#  'amar': 196,
#  'ngeluh': 4692,
#  'lau': 3696,
#  'usaha': 6905,
#  'biar': 839,
#  'diinjek': 1439,
#  'sikocam': 6134,
#  'cnnindonesia': 1177,
#  'anjing': 258,
#  'siaa': 6100,
#  'goblokkkk': 2049,
#  'bajingan': 509,
#  'mending': 4166,
#  'jabatan': 2866,
#  'kasih': 3171,
#  'sakit': 5794,
#  'jiwaaaa': 3005,
#  'wildn': 7043,
#  'adinduuh': 46,
#  'graveyeez': 2082,
#  'salah': 5799,
#  'athy': 411,
#  'kiai': 3440,
#  'dpo': 1653,
#  'moch': 4412,
#  'subchi': 6294,
#  'azal': 455,
#  'tsani': 6779,
#  'masih': 3984,
#  'aman': 192,
#  'bersembunyi': 795,
#  'balik': 520,
#  'ketiak': 3411,
#  'sang': 5827,
#  'ayah': 440,
#  'yâ': 7159,
#  'hetersmu': 2227,
#  'kumpulan': 3610,
#  'goblok': 2048,
#  'begini': 652,
#  'belain': 668,
#  'tersangka': 6601,
#  'konteksnya': 3533,
#  'lainâ': 3661,
#  'httpstcozmwmmjlj': 2669,
#  'hienzzo': 2238,
#  'sy': 6377,
#  'bkn': 878,
#  'cwe': 1234,
#  'mau': 4007,
#  'sm': 6205,
#  'cwo': 1235,
#  'buaya': 981,
#  'macam': 3859,
#  'kaungaku': 3184,
#  'suka': 6313,
#  'selingkuhtp': 5977,
#  'nyampah': 4857,
#  'slh': 6198,
#  'kaâ': 3194,
#  'httpstcopihzhrcbmx': 2529,
#  'nikmatin': 4759,
#  'idup': 2727,
#  'lakuin': 3668,
#  'hal': 2147,
#  'dengan': 1324,
#  'berlindung': 777,
#  'dibalik': 1375,
#  'kata': 3175,
#  'setia': 6069,
#  'diâ': 1602,
#  'httpstcorbllrxampk': 2549,
#  'robet': 5726,
#  'cintada': 1156,
#  'kangdede': 3139,
#  'berlianidris': 775,
#  'dah': 1252,
#  'bau': 602,
#  'kadrun': 3094,
#  'gitu': 2030,
#  'deh': 1309,
#  'hasilnya': 2195,
#  'nalar': 4560,
#  'logika': 3802,
#  'sopan': 6232,
#  'santun': 5837,
#  'hatinya': 2200,
#  'dipenâ': 1512,
#  'gasabaran': 1952,
#  'bat': 596,
#  'siiii': 6132,
#  'cincin': 1153,
#  'ayangðÿ': 444,
#  'mana': 3929,
#  'pos': 5413,
#  'nya': 4845,
#  'haizðÿ': 2141,
#  'bol': 921,
#  'sinchanâœ': 6149,
#  'qwertyouipsn': 5553,
#  'lho': 3747,
#  'jistru': 3003,
#  'sinetron': 6150,
#  'harus': 2190,
#  'memberi': 4095,
#  'nilai': 4761,
#  'baik': 506,
#  'utk': 6923,
#  'penonton': 5216,
#  'dibahas': 1372,
#  'sinetrâ': 6151,
#  'httpstcohfqxpikr': 2395,
#  'restycayah': 5680,
#  'polisi': 5395,
#  'teman': 6501,
#  'jokowi': 3026,
#  'dijemput': 1443,
#  'httpstcoxcifcjdop': 2637,
#  'jempolrakyat': 2972,
#  'abymany': 24,
#  'bobbyandhika': 903,
#  'sdh': 5881,
#  'pelecehan': 5117,
#  'penghinaan': 5198,
#  'terhadap': 6561,
#  'menggalharap': 4208,
#  'divhumaspolri': 1598,
#  'ccicpoâ': 1094,
#  'smstantuwir': 6211,
#  'kpopers': 3571,
#  'kamu': 3132,
#  'kehilangan': 3255,
#  'rasa': 5607,
#  'kemanusiaan': 3315,
#  'coba': 1179,
#  'ingat': 2792,
#  'kembali': 3321,
#  'ngestan': 4710,
#  'idolamu': 2725,
#  'ujaran': 6858,
#  'kebâ': 3229,
#  'beean': 648,
#  'linda': 3766,
#  'amechivaaree': 202,
#  'belajar': 669,
#  'ngetik': 4711,
#  'benar': 684,
#  'dlu': 1612,
#  'soalnya': 6216,
#  'keliatan': 3298,
#  'tata': 6462,
#  'bahasanya': 503,
#  'caur': 1091,
#  'urv': 6903,
#  'podcastretropus': 5380,
#  'kon': 3513,
#  'iku': 2747,
#  'jancok': 2915,
#  'bajingaaaan': 508,
#  'ngisinngisini': 4724,
#  'wong': 7067,
#  'waeðÿ': 6974,
#  'bambang': 523,
#  'genugenuw': 1992,
#  'tuh': 6794,
#  'singkatan': 6156,
#  'mita': 4388,
#  'is': 2831,
#  'bukan': 1001,
#  'are': 338,
#  'toeflnya': 6711,
#  'nyogok': 4883,
#  'tatjanaâ': 6465,
#  'udah': 6844,
#  'capek': 1076,
#  'ngatur': 4673,
#  'skor': 6190,
#  'vietnam': 6950,
#  'thailand': 6637,
#  'ndak': 4611,
#  'lolos': 3810,
#  'duanya': 1681,
#  'mang': 3938,
#  'negara': 4621,
#  'jika': 2996,
#  'memungkinkan': 4125,
#  'sebaiknya': 5889,
#  'persidangan': 5286,
#  'dilakukan': 1467,
#  'diluar': 1479,
#  'agar': 82,
#  'mudah': 4472,
#  'terjadi': 6568,
#  'mobilisasi': 4410,
#  'masa': 3977,
#  'untuk': 6890,
#  'menekâ': 4173,
#  'qardust': 5548,
#  'sehunkw': 5939,
#  'masi': 3983,
#  'belum': 680,
#  'diganti': 1417,
#  'lonte': 3814,
#  'bner': 895,
#  'tu': 6786,
#  'zivaal': 7178,
#  'para': 5046,
#  'tua': 6787,
#  'anaknya': 217,
#  'pernahsedang': 5276,
#  'nyantri': 4858,
#  'disana': 1546,
#  'harap': 2177,
#  'menanyakan': 4140,
#  'apakah': 305,
#  'pernah': 5275,
#  'mengalami': 4185,
#  'kejadian': 3259,
#  'pengarangsajak': 5184,
#  'semoga': 6000,
#  'gejala': 1979,
#  'covid': 1211,
#  'mampus': 3924,
#  'bodat': 911,
#  'rajasmara': 5577,
#  '²ðÿ': 7192,
#  'penggila': 5191,
#  'sosmed': 6240,
#  'selesai': 5974,
#  'sudah': 6301,
#  'dituntut': 1593,
#  'divonis': 1600,
#  'hukuman': 2690,
#  'lukman': 3835,
#  'hakim': 2145,
#  'aksaa': 135,
#  'wahyuress': 6980,
#  'utdfocusid': 6922,
#  'team': 6482,
#  'nunggak': 4835,
#  'gaji': 1923,
#  'pemain': 5124,
#  'club': 1173,
#  'liga': 3758,
#  'malu': 3917,
#  'hahaha': 2135,
#  'jendol': 2975,
#  'utangjpu': 6918,
#  'ngetweet': 4712,
#  'tanpa': 6448,
#  'donasi': 1634,
#  'duh': 1684,
#  'perkara': 5270,
#  'tea': 6481,
#  'matcha': 4001,
#  'doang': 1621,
#  'bahkan': 504,
#  'rumah': 5758,
#  'segininya': 5929,
#  'ribet': 5700,
#  'jd': 2955,
#  'manusiaâ': 3956,
#  'httpstcoxzdhdads': 2648,
#  'nessa': 4642,
#  'rasheedinn': 5610,
#  'memakai': 4076,
#  'allah': 177,
#  'memuaskan': 4124,
#  'melampiaskan': 4052,
#  'model': 4420,
#  'gini': 2023,
#  'sesungguhnya': 6061,
#  'perusak': 5305,
#  'agama': 79,
#  'guna': 2103,
#  'ngomongi': 4730,
#  'untungnya': 6893,
#  'merereka': 4319,
#  'kejar': 3268,
#  'hanya': 2171,
#  'tulang': 6800,
#  'daging': 1250,
#  'lemâ': 3726,
#  'httpstcodqqkhsw': 2350,
#  'muhamadhendrik': 4475,
#  'transclub': 6750,
#  'rehat': 5648,
#  'socmed': 6217,
#  'lucinta': 3825,
#  'luna': 3840,
#  'kali': 3113,
#  'bedah': 643,
#  'potong': 5416,
#  'leher': 3716,
#  'menghilangkan': 4221,
#  'suara': 6290,
#  'khodamnya': 3434,
#  'republik': 5668,
#  'indonesia': 2775,
#  'telah': 6494,
#  'abai': 7,
#  'menjaga': 4253,
#  'keselamatan': 3389,
#  'jiwa': 3004,
#  'kesehatan': 3386,
#  'rakyat': 5584,
#  'orgâ': 4953,
#  'akibat': 132,
#  'main': 3883,
#  'sabun': 5779,
#  'tau': 6467,
#  'bakal': 512,
#  'licin': 3756,
#  'jatuh': 2939,
#  'zombieq': 7181,
#  'tvonenews': 6821,
#  'disetir': 1554,
#  'konpers': 3523,
#  'isilop': 2833,
#  'ajudan': 119,
#  'selengki': 5973,
#  'istri': 2845,
#  'bossâ': 950,
#  'httpstcoolqeqjrpp': 2512,
#  'freepalestineðÿ': 1891,
#  'µðÿ': 7195,
#  'indihomecare': 2769,
#  'woy': 7072,
#  'dm': 1613,
#  'in': 2764,
#  'cs': 1213,
#  'dibales': 1374,
#  'bales': 518,
#  'anjink': 264,
#  'rep': 5666,
#  'iâ': 2864,
#  'serius': 6046,
#  'becanda': 639,
#  'utang': 6917,
#  'bayar': 609,
#  'tololsi': 6723,
#  'jenocremeooo': 2982,
#  'cok': 1183,
#  'usah': 6904,
#  'sok': 6219,
#  'an': 212,
#  'take': 6422,
#  'pc': 5077,
#  'ksian': 3590,
#  'admin': 51,
#  'giniin': 2024,
#  'beâ': 825,
#  'jasjusâ²â': 2934,
#  'imxoyjoy': 2763,
#  'jeeyeaj': 2959,
#  'tanyakanrl': 6451,
#  'menurutku': 4283,
#  'ujian': 6860,
#  'nunjukkin': 4838,
#  'berdua': 736,
#  'pasangan': 5060,
#  'berâ': 817,
#  'cek': 1100,
#  'pinned': 5348,
#  'tweetðÿ': 6824,
#  'seseorang': 6055,
#  'terlahir': 6579,
#  'adanya': 34,
#  'kemelekatan': 3323,
#  'melekat': 4064,
#  'kenikmatan': 3342,
#  'ia': 2702,
#  'ingin': 2797,
#  'menikmati': 4243,
#  'maka': 3886,
#  'iaâ': 2705,
#  'httpstcolrqzcjrw': 2448,
#  'skysphire': 6195,
#  'dago': 1251,
#  'real': 5629,
#  'mh': 4342,
#  'samperin': 5820,
#  'rumahnya': 5759,
#  'trs': 6774,
#  'cekek': 1101,
#  'sambil': 5812,
#  'teriak': 6565,
#  'jujur': 3048,
#  'cepetan': 1107,
#  'nanti': 4579,
#  'nyesel': 4877,
#  'aku': 141,
#  'cinta': 1155,
#  'mah': 3872,
#  'dihindarin': 1434,
#  'penyakit': 5223,
#  'disamperin': 1545,
#  'lolll': 3808,
#  'akaja': 124,
#  'kibulin': 3443,
#  'habib': 2123,
#  'kribo': 3574,
#  'zin': 7176,
#  'ahsiyap': 99,
#  'elpiji': 1739,
#  'bbm': 619,
#  'indomie': 2773,
#  'papua': 5045,
#  'dihargai': 1431,
#  'senilai': 6020,
#  'baju': 510,
#  'lebaran': 3707,
#  'per': 5232,
#  'bungkusnya': 1019,
#  'idih': 2722,
#  'ava': 424,
#  'pakek': 4993,
#  'ngatain': 4672,
#  'dk': 1604,
#  'tweet': 6822,
#  'justru': 3071,
#  'sayang': 5863,
#  'persib': 5285,
#  'sebuah': 5907,
#  'penggembosan': 5190,
#  'no': 4781,
#  'omat': 4917,
#  'bobotohâ': 905,
#  'httpstcolqknvfbwgu': 2447,
#  'ramalan': 5593,
#  'zodiak': 7180,
#  'besok': 820,
#  'sabtu': 5778,
#  'juli': 3052,
#  'aries': 346,
#  'taurus': 6469,
#  'gemini': 1986,
#  'segera': 5926,
#  'singkirkan': 6157,
#  'hati': 2198,
#  'tasyâ': 6461,
#  'httpstcolohptsu': 2442,
#  'hamimbud': 2160,
#  'jujuswan': 3049,
#  'opo': 4938,
#  'mungkin': 4506,
#  'jawab': 2944,
#  'simple': 6146,
#  'presidene': 5434,
#  'isok': 2840,
#  'keuangan': 3422,
#  'ngene': 4693,
#  'weâ': 7024,
#  'inmyego': 2802,
#  'nichosilalahi': 4748,
#  'loe': 3801,
#  'tololbentar': 6720,
#  'ketauan': 3401,
#  'kronologisnyagk': 3587,
#  'asap': 371,
#  'api': 316,
#  'yono': 7139,
#  'bubut': 985,
#  'androidak': 233,
#  'tanya': 6449,
#  'kemana': 3313,
#  'mahasiswa': 3878,
#  'ketika': 3412,
#  'naik': 4548,
#  'tabrani': 6397,
#  'ngurus': 4739,
#  'pertaikmina': 5296,
#  'taik': 6416,
#  'iya': 2858,
#  'dpt': 1659,
#  'untung': 6892,
#  'petronas': 5322,
#  'rugi': 5754,
#  'triliun': 6770,
#  'sekarang': 5954,
#  'hargâ': 2183,
#  'arularularula': 361,
#  'layak': 3702,
#  'sebut': 5910,
#  'intelektual': 2813,
#  'giman': 2017,
#  'kita': 3454,
#  'telektua': 6496,
#  'liputandotcom': 3779,
#  'negeri': 4626,
#  'ttp': 6785,
#  'turun': 6810,
#  'harga': 2180,
#  'bahan': 500,
#  'pokok': 5391,
#  'meroket': 4325,
#  'berhasil': 749,
#  'dinilai': 1496,
#  'segi': 5928,
#  'dirgantara': 1535,
#  'sebel': 5896,
#  'najisssss': 4558,
#  'ad': 30,
#  'makannya': 3889,
#  'nyeplakkk': 4873,
#  'apaan': 301,
#  'gblkkkkk': 1968,
#  'brisik': 968,
#  'makan': 3887,
#  'nyeplakðÿ': 4874,
#  'ncaaa': 4609,
#  'taerbucin': 6407,
#  'siargorival': 6114,
#  'gedeg': 1974,
#  'liatnya': 3752,
#  'gebleg': 1971,
#  'argo': 343,
#  'teh': 6491,
#  'pisan': 5352,
#  'anjrit': 272,
#  'apalagi': 306,
#  'vid': 6946,
#  'tiktoknya': 6672,
#  'eta': 1794,
#  'hih': 2239,
#  'kala': 3109,
#  'miawmeow': 4345,
#  'lionparcel': 3778,
#  'jgn': 2990,
#  'lg': 3742,
#  'supply': 6352,
#  'chain': 1121,
#  'busuk': 1035,
#  'barang': 580,
#  'macet': 3861,
#  'gudangageâ': 2098,
#  'httpstcolxqwvjxjr': 2456,
#  'doppelgã': 1642,
#  'nger': 4699,
#  'siotakdungu': 6168,
#  'kamis': 3126,
#  'siang': 6103,
#  'memberikan': 4096,
#  'sinyal': 6164,
#  'tak': 6420,
#  'akan': 126,
#  'menaikan': 4132,
#  'energi': 1764,
#  'subsidi': 6296,
#  'seperti': 6033,
#  'pertalite': 5297,
#  'lpg': 3821,
#  ...}

# %%
#kolom pertama ini berarti nomor urutan data
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 1848)	1
#   (0, 3823)	1
#   (0, 5346)	1
#   (0, 5749)	1
#   (0, 6719)	1
#   (0, 7118)	1
#   (0, 7224)	2
#   (1, 1746)	1
#   (1, 2720)	1
#   (1, 2991)	1
#   (1, 3823)	1
#   (1, 5749)	1
#   (1, 5806)	1
#   (1, 6636)	1
#   (1, 6719)	1
#   (1, 6949)	1
#   (2, 55)	1
#   (2, 537)	1
#   (2, 1347)	1
#   (2, 1746)	1
#   (2, 2382)	1
#   (2, 3388)	1
#   (2, 5749)	1
#   (2, 6099)	1
#   (2, 6719)	1
#   :	:
#   (1127, 1907)	1
#   (1127, 1910)	1
#   (1127, 2945)	1
#   (1127, 3199)	1
#   (1127, 3412)	1
#   (1127, 3488)	1
#   (1127, 3497)	1
#   (1127, 3725)	1
#   (1127, 3823)	1
#   (1127, 4045)	1
#   (1127, 4612)	1
#   (1127, 4670)	1
#   (1127, 4945)	1
#   (1127, 5676)	1
#   (1127, 5749)	1
#   (1127, 5956)	1
#   (1127, 6225)	1
#   (1128, 890)	1
#   (1128, 1150)	1
#   (1128, 1636)	1
#   (1128, 2230)	1
#   (1128, 3331)	1
#   (1128, 3497)	1
#   (1128, 5951)	1
#   (1128, 6724)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# rt idextratime tolol emang lu viet sama thai jiahelahlu

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 1746)	1
#   (0, 2720)	1
#   (0, 2991)	1
#   (0, 3823)	1
#   (0, 5749)	1
#   (0, 5806)	1
#   (0, 6636)	1
#   (0, 6719)	1
#   (0, 6949)	1

# %%
#hasil perhitungan tf idf dalam 1 doc
dokumen = term_fit.transform(Ulasan) 
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

#hasil manual dengan sistem pyhton
tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf)
# Out:
# [6.93136062 7.33682573 7.33682573 ... 7.33682573 7.33682573 6.93136062]
#   (0, 6949)	0.44306640516674856
#   (0, 6719)	0.24451955107314619
#   (0, 6636)	0.39875905394895195
#   (0, 5806)	0.24645672949863281
#   (0, 5749)	0.13847688752334192
#   (0, 3823)	0.19695728604501014
#   (0, 2991)	0.4689845441354414
#   (0, 2720)	0.3803698416998483
#   (0, 1746)	0.3186799446421324

# %% [markdown]
# VISUALISAI DATA

# %%
import matplotlib.pyplot as plt # Untuk Memvisualisasikan Data

# %%
data_sentimen = data[["text", "label"]]

# %%
sentimen_data=pd.value_counts(data_sentimen["label"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red"])
plt.title('Data Sentimen')
plt.show()

# %% [markdown]
# SPLIT TRAINING DAN TESTING

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data['text'], data['label'], test_size=0.1,  random_state=30)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1016, 6722)
# (113, 6722)

# %%
X_train = X_train.toarray()

# %%
X_test = X_test.toarray()

# %% [markdown]
# MODEL NAIVE BAYES

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()

# %%
# Membangun MultinomialNB model
NB_model = MultinomialNB()

# training!
NB_model = NB_model.fit(X_train, y_train)

# predict!
y_train_pred = NB_model.predict(X_train)
y_test_pred = NB_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc_train = accuracy_score(y_true=y_train, y_pred=y_train_pred)
acc_test = accuracy_score(y_true=y_test, y_pred=y_test_pred)

# %%
nb = MultinomialNB()

# %%
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred_nb = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report,log_loss,f1_score, accuracy_score

# %%
#TN FN
#FP TP
print('confusion matrix')
print(confusion_matrix(y_test, y_pred_nb))
print('\n')
print('Hasil klasifikasi Naive Bayes ')
print(classification_report(y_test, y_pred_nb))
# Out:
# confusion matrix
# [[20 27]
#  [ 2 64]]
#
#
# Hasil klasifikasi Naive Bayes
#               precision    recall  f1-score   support
#
#      negatif       0.91      0.43      0.58        47
#      positif       0.70      0.97      0.82        66
#
#     accuracy                           0.74       113
#    macro avg       0.81      0.70      0.70       113
# weighted avg       0.79      0.74      0.72       113

# %%
# let’s plot the confusion matrix as follows

cm = confusion_matrix(y_test, y_pred_nb)
plt.figure(figsize=(5,5))
sns.heatmap(data=cm,linewidths=.5, annot=True,square = True,  cmap = 'Blues')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format(nb.score(X_test, y_test))
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.7433628318584071')

# %%
nb = MultinomialNB()
nb.fit(X_train, y_train)

pickle.dump(vectorizer,open('vectorizer.pkl','wb'))
pickle.dump(nb,open('nb.pkl','wb'))
model = pickle.load(open('nb.pkl','rb'))

y_pred_nb = nb.predict(X_test)
print("NB Accuracy Score -> ",accuracy_score(y_pred_nb, y_test)*100)
print(y_pred_nb)
# Out:
# NB Accuracy Score ->  74.33628318584071
# ['negatif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'negatif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'negatif' 'positif' 'positif' 'negatif' 'positif' 'negatif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'negatif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'negatif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'positif'
#  'positif' 'positif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'positif' 'negatif' 'positif' 'positif' 'positif' 'positif' 'negatif'
#  'negatif']
